# %%
import tensorflow as tf
import numpy as np

# %%
def get_text_data():
    with open("data/shakespeare.txt","r") as text_file:
        data=text_file.read()
        data=data.replace('\n','')
        data=data.replace('$','')
    lis=list(set(data))    
    total_char,unique_char=len(data),len(lis)
    print ('data has %d characters, %d unique.' %(total_char, unique_char))
    char_to_ix = { ch:i for i,ch in enumerate(lis) }
    ix_to_char = { i:ch for i,ch in enumerate(lis) }
    return total_char,unique_char,char_to_ix,ix_to_char,data

def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# %%
total_chars,unique_chars,char_id,id_char,data=get_text_data()
# Out:
# data has 1075393 characters, 63 unique.

# %%
print(char_id)
# Out:
# {':': 0, 'u': 1, 'o': 2, 'Y': 3, 'L': 4, ';': 5, 'J': 6, 'e': 7, 'E': 8, 'p': 9, "'": 10, '-': 11, '3': 12, 'y': 13, 'g': 14, 'P': 15, 'G': 16, 'n': 17, '!': 18, '&': 19, 'l': 20, 'w': 21, 'W': 22, 'r': 23, 'N': 24, 'a': 25, 'h': 26, 'x': 27, 'z': 28, 'v': 29, 'f': 30, 'F': 31, 'U': 32, 'b': 33, 'B': 34, 'V': 35, 'Q': 36, 'c': 37, 'A': 38, 'K': 39, 's': 40, 'm': 41, 'I': 42, 'j': 43, 'q': 44, ' ': 45, 'Z': 46, 'O': 47, 'i': 48, 'k': 49, '.': 50, 'S': 51, 'H': 52, 'C': 53, ',': 54, 'T': 55, 't': 56, 'd': 57, 'X': 58, 'M': 59, 'D': 60, 'R': 61, '?': 62}

# %%
# def generate_next_batch(seq_len,seed):
#     a=np.zeros((seq_len,1,unique_chars))
#     b=np.zeros((seq_len,unique_chars))
#     for t in range(seq_len):
#         a[t][0][char_id[data[t]]]=1
#         b[t][char_id[data[t+1]]]=1
#     return a,b,char_id[data[seed]]

# %%
def generate_next_batch(seq_length,p):
    inputs = [char_id[ch] for ch in data[p:p+seq_length]]
    targets = [char_id[ch] for ch in data[p+1:p+seq_length+1]]
    inputs=np.array(inputs).reshape(seq_length,1)
    targets=np.array(targets).reshape(seq_length,1)
    return inputs,targets

# %%
#test generator function here
def generator(seed_i,n):
    x=np.zeros((1,1))
    x[0][0]= seed_i
    ixes=[]
    for t in range(n):
        p=sess.run(prediction,{X:x})
        ix = np.random.choice(range(unique_chars), p=p.ravel())
        x[0][0]=ix
        ixes.append(ix)
    return ixes

# %%
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1
n_neurons = 300
n_layers = 1 #3

# %%
def build_rnn(x):
        with tf.name_scope('rnn'):
            cell= tf.contrib.rnn.BasicRNNCell(num_units=hidden_size, activation=tf.nn.relu)
            outputs, states = tf.nn.dynamic_rnn(cell, x, dtype=tf.float32)
            return outputs,states

# %%
reset_graph()
X=tf.placeholder(tf.float32,[None,1])
Y=tf.placeholder(tf.float32,[None,1])
X=tf.cast(X,tf.int32)
X_onehot=tf.one_hot(X,unique_chars)
Y=tf.cast(Y,tf.int32)
Y_onehot=tf.one_hot(Y,unique_chars)
outputs,states=build_rnn(X_onehot)
outputs=tf.transpose(outputs,perm=[1,0,2])
W=tf.random_normal((hidden_size,unique_chars),stddev=0.01)
B=tf.Variable(tf.constant(0.0,shape=(1,unique_chars)))
Ys=tf.matmul(outputs[0],W)+B
prediction = tf.nn.softmax(Ys)
cross_entropy=tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=Y_onehot,logits=Ys))
optimizer = tf.train.AdamOptimizer(learning_rate)
minimize = optimizer.minimize(cross_entropy)
mistakes = tf.not_equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
error = tf.reduce_sum(tf.cast(mistakes, tf.float32))

# %%
init=tf.global_variables_initializer()

# %%
batch_size=1000
no_of_batches=int(total_chars/batch_size)
epoch=5000
ptr=0
with tf.Session() as sess:
    sess.run(init)
    for i in range(epoch):
        print("epoch ",i)
        if ptr+batch_size+1 >= len(data): 
            ptr=0
        for j in range(no_of_batches):
            inputs,targets=generate_next_batch(batch_size,ptr)
            ptr+=batch_size
            if(j%100==0):
                loss=sess.run(cross_entropy,feed_dict={X:inputs, Y:targets}) 
                sample_ix=generator(inputs[0],200)
                txt = ''.join(id_char[ix] for ix in sample_ix)
                print('iteration %i epoch %i loss %f'%(j,i,loss))
                print ('----\n %s \n----' % (txt, ))
            sess.run(minimize,feed_dict={X:inputs,Y:targets})
# Out:
# epoch  0
# iteration 0 epoch 0 loss 4.143891
# ----
#  rMZcppY,cquRHy--&bx!AE!rzk3UcoA'LMD.&JjxeFodGm&UB-RiMtcX;3olNnHWnBE.L?i3:Sq iLWe,KlY&l sTveqOViFUhuJus&UdPaOgL!'X.K,.-tb.tlJghS,:UhgewMlUqWRDPF!noAFYndPpf?PIOP rKKb;Hl-ocIuUgs'jNMEweXTGmSBbP;ttKwW tTk
# ----
# iteration 100 epoch 0 loss 3.226083
# ----
#  Ioe,m:e :ec  ' yl IiIsornyda,m vshe nuIetttrutadtinNilest somMefC   r!iO.tbf j  ,wrosohcnsuoireU 'mooccI dUl naouti aeegc  nt cmayr ueooi hLvheaasmormfk eomustsNIhstNtteoouo oliuOne IS  ne  Mar rtka
# ----
# iteration 200 epoch 0 loss 3.239969
# ----
#  LthiltrutolddsIanl  O ohoca,Wee moo oi oodrritd ro Aatehuhoee  sdrn,EdudoTfDocdfm amstondtamnehwsodd bni etid mrtCouriXesrdiihrnoCi?Rc t.yaeds' mre v f.cc,reu m eeuWsratWv rm,dethGadhlIyoeeee ewth eeo
# ----
# iteration 300 epoch 0 loss 3.167826
# ----
#  eneoehyrf oiIo,toni Eyrvmrh on tUcehAnnruwyletm  focs aenr srDmgeeneEletobadead,ine tssn pwaFnemlsevBoweoRlin  shartide teo skeOyeei cr,Niarhl fgtNKtmetIweimct eln os ,riekeaieg    KnretsahtesFmu,ts t
# ----
# iteration 400 epoch 0 loss 3.278451
# ----
#   esma tthediet,csaowO:wactrr hyheefatrsju edeaoRfso yt'Eohso hbaaseeHtrn aue  uyg ue e gLn .iN yltuo'uesatiwnrsnIasant e,htOaunA neidbenutesnK i'uet,sm etarboe osnNnr lsh t yunsofmw eo v ani  nsrYteta
# ----
# iteration 500 epoch 0 loss 3.228392
# ----
#  ec, i  SnhyMto testu !tdth,Cliosyeo w olcilmTmyu,u,bti?W ahm,d aa gern!youMar ytOoaTthmeRyt mfyeye WodTtRea  eiyyBsso,nett,i coarn hoy o,vhsiw snTi C, k  m eT,uiel eiif:nmdInIc e VdwIt;t ol oswmo,dd e
# ----
# iteration 600 epoch 0 loss 3.180229
# ----
#   uuwh  anRaheO go  nteata Nndatgyo r,hdp,  k meotmihee ayhosnilhuorhsl C ohendevm AuwforooNes iyee  otoc , iWiotcih U oone,gdwp  zA gRd y ounh,  arrMo,sa h,tanstymI e tpndp.hn,afrserdn w edhnoefwianm
# ----
# iteration 700 epoch 0 loss 3.275049
# ----
#  eeo  hiOsSpeGobtoeatnvoedd:tIHafh eun p do aSe it hmHsut  ' r e ?odrC s ,Nl i  aiec:lwr rayryos mar.fhulrrsbs i tuE: Tytotl;hgnnOQns naee eU esgdhicomtsi,y'sNiTly nia Lmase .'LuImcyrshXe ra  Mee snoo,
# ----
# iteration 800 epoch 0 loss 3.298941
# ----
#  el-rofo yU,IUll M c hoste eboa w  tyredtbifmo ei  olnrotclrasvthdipteirC.  lore wdmiekths ehrerouetQdalha;mpsIeo hoMo dyeelL ohDOslmfae,aerai  uahun eUpuyd thebaiYhel hrrh ,t l agioThm ,Isove v oo oou
# ----
# iteration 900 epoch 0 loss 3.412516
# ----
#  t rnW  eeo  nuodn mrEes Ifod ndss O ewt-raastyee,InOkitg ai   ebdtoee ipvi bsvnc .m ea:g MoN Ec ser c: u EtrlenSDra ,sra :mr oshmosccs  nihoow   vaelao-s ?tmam eNirAserluuinvntPa.ie aheo ha  ese  toon
# ----
# iteration 1000 epoch 0 loss 3.356372
# ----
#  nPTnn h ohootecarTu tstoan dn EshdmreeyPisbe. o cohheti ha AoUOho pnew bp,,Cghd uohtcfe ir tpbn sI atce  l.tndepe, eamo, fdad Ie,aeusB ,o e.ic lhihrviwe i;gerh  mrihdIe w oekyin  Ul'ol tC   nt sehhSAr
# ----
# epoch  1
# iteration 0 epoch 1 loss 3.265681
# ----
#  d;ao tn.nt Oud linSe cog:h!snn oTk s,eogOusRkfoiseot iSAfala s,asms yvorhIts vmoPWhoendlhesnpf::-u;wOAfntrosewvSh RenraaT sliti:monos erarea ooWt  rs:mtsS eTobe:anhsoeAw Ii a nl aOi.talsrs  reae,weuIm
# ----
# iteration 100 epoch 1 loss 3.228376
# ----
#  loal srpda ehuvdroureu an,etl,sidntrrlbecb iangeowndcwseamhaDSmsmeNohB'dt b.e e nStehdhksrne rvhskdai steeiai,oCavmtuh   enW nEt:R inu i e  I isohoaaowe totfnoh  ooanyn taTlh'mdsWIe,hasmo y i cfe nhne
# ----
# iteration 200 epoch 1 loss 3.236846
# ----
#  Io l:fon oi:G lornil tatrdo hr  :e  d d !Y  ordhahErro aikp h,p mne  l r eTnroefniurwueNhrbs:hdf l  fdeu ienun fWr:l dkut  hrloygh hodt Mcdoryeem sei r nwtnhT oe: aedbgh onihcaoeaEoid .gdedR dsnasomde
# ----
# iteration 300 epoch 1 loss 3.161062
# ----
#   ttdcd ev n  es fu:rtg gw. Lauv elatRo ra ttsr nsr npteUgooeCntshsB nrttta vfympw.yootbaiiW   e,Anaoe :acodgllg: dg  .alw iErtiM am os e sdonml  ebbrti  ht  Hni'rrdS  stfre  ruiu dhG isdoU HeisaeCell,
# ----
# iteration 400 epoch 1 loss 3.278220
# ----
#    nIsitu oKnlrIw ao na wort   'a ennadobedea  aranyhnn dmootlYmI nudn  mlnsCteet ,'s  ausnhdaip deuaL tana usm n Y', unynnoh m otiiitA'm  bortscnrt  h n aa toilhulfovte a neeoE ,i enlnUcrri lttwrft,ea
# ----
# iteration 500 epoch 1 loss 3.226400
# ----
#  cfE, i, ame e yee:  beouetPreybmnoagydmAaac  efa, bemewe 'atpfauOohsI nu ViikhwOheCThoNitpo,acdo oria?slyrrorh   :y h:i co s  ibe m eEt t s ts eh nplPyatfeo ri in nt lnE ysn i  eo raunu,nAo ltTltRi.ns
# ----
# iteration 600 epoch 1 loss 3.180386
# ----
#  oL?w iHRnoaeur Kl gu m oimAm,ssD a rgsttWfyRd i soh  rtev   ne sE h keu s kidbhNesntssrooaosTT y,t- niRutmdhkowodi.toroyghneeed daniwlgenr oyieW,eohlAiesvemnhohlioah s  ,lbkDtr'h hhkrCawh e-teKsh gcr
# ----
# iteration 700 epoch 1 loss 3.275350
# ----
#  esen'eintdser WLAi e -'Cyg:H m eawYhtonpythh ehas? rieuplfmtfxoocaieuayo esnerOr e y strouib ylut tgm lit, nndu  mMnloaglitertooesedazyh   sti o:' ar,Ttn nEelaie bnhnsaeectl  tis Trlui eshed'os u bees
# ----
# iteration 800 epoch 1 loss 3.299586
# ----
#  ntidPdawoo a-sgsriihwr lpohhi'rOira!tet fohNeIdc oaest owbriisrg;wa  oreeioae,cyh t',ttmmr f a ieibiartgihvlslon:ddr w  tr ndus  etes'lbaeea TorYu seyuidey.taoosrusu losrdbn ntrboai '-itoalSop ohalrfe
# ----
# iteration 900 epoch 1 loss 3.412177
# ----
#  K  eenrN our eIG,,nyay i ire r noMedd  sknhsaalciEt ic uio,Mnp gkoed il ss san y ym poesio whtlhuoPumaVen to,schooswtNe nf T   tn:np msu l cweoitIor  e: rgubitcvoVrsryoloedaU.DsOlnN  lemes   .h seunas
# ----
# iteration 1000 epoch 1 loss 3.355525
# ----
#  iEetehscooesAyqiof nlmTOs r he srtulo  w a hatnesdroWUe ?hrae,aN h oit tehmsaWeae 'oKsCsr costaleeasot siohIi nte,de oabst hOtudoinea romTr-hoiisr siI satcmyIseom By oheepNoabhriefooss,stoYoec otiloee
# ----
# epoch  2
# iteration 0 epoch 2 loss 3.266639
# ----
#  efgrD terco: mNhauweots lryoeO chtonw RgSiyrNdeOl aAiO.o eacNfRe reetHTRpW harsAehcAp uW An AO shenasfn:hn ustehomcNf,eu.A,sia tAeneglcsasooef'nri:I Otue,aA  tR nHoy,P'e.h y  lNpdIt!   dre  ApvlaI yNn
# ----
# iteration 100 epoch 2 loss 3.228570
# ----
#  e Tr ,ietrwoheyl Snii e t lhIfel ietl   tlie   g.eo hireice fshii ei  rS eaCot mnytn Ne:cdrrwfaSvvedyo saa eOIahg flsRatwoeap:ti eeo taefwrm euRyoeoN wa vik: hdhd ybMiL w:ayOli:!yyoecnarSThletonnle em
# ----
# iteration 200 epoch 2 loss 3.237310
# ----
#  eoteicodg.e.uf tti,ennrrce elv   ecoraonddroerde ;dr wIeett,Iiowl resireeyl s rieh e;,w u lomgroe!ot:heltede c,cbeetlr wd s,onhy tawdahrts iwakr tI iiror a r e cen hpd dahtU Gaee:odg ice s  dsw otelis
# ----
# iteration 300 epoch 2 loss 3.161012
# ----
#  ah.r,o .eae cq'yowsS ad tcno elcsmermd t mp ImfcWB'iEoa ansrttfw ohrtus vodbmGvaoeiG'F oseooieoaknaohsswler; ddCm !Ihv nltoftmsnr.sb;udrmo tses a, tIelyt  lE hgmowheMyey asuohi,oAtNiet t rtnw  tyi oNn
# ----
# iteration 400 epoch 2 loss 3.277495
# ----
#  ld  drOa,etyw amh golheraos,es a af:  ordaft sOHhhrd oHhoKa,-isodF!h.lpel hgewtrMheTh do; nEou ehmau u tachNTtwmtdfhndesnna?osoeafnloldtwst:itYedcunh  Rnccaed.fmgA UDmr erra h sWiPyfnu fhdsHes,s rLha,
# ----
# iteration 500 epoch 2 loss 3.225688
# ----
#  nddnrtdhlb n ooarlvlEldahsdn  mo om -kukhyetoprIce!gya yradtinolnf ,kr lo uaw  lilh  My mte snhwsTs bogvleflnhet, e i e is hbu oalce ieee,bhe ,iIoeonenNtmi e n w?nntu  iddoi  e dthori hoaht lbodrhr
# ----
# iteration 600 epoch 2 loss 3.181148
# ----
#  nle os,taho inak,nc'eti okaWco sppposkuosiwrsnu ms  yree Cdmpeism  io .n ldose ePhtye xte ge s laadllrAntnte tedht lplYeeaiee -;etir b  mnohtsiDe  dd nie trIaal tte, nontI n urmeig aseutni?yn dtviedde
# ----
# iteration 700 epoch 2 loss 3.275395
# ----
#  n;niroldmaedinooesthia  ewIowbRhia s,NsmaeYuCy' lvetkSN e:usaf:a a yis'ymiagS ahpmwRhhstOa shEhytltbmcerLma -eNt afod nsede y   m,olyXr  'ynNyu,dll: iee momnW irtN hTtoti pOintoeVsIutoeust iucaho v he
# ----
# iteration 800 epoch 2 loss 3.299636
# ----
#  meSsetvosg idha ebboaikYonCe LsW ymy He.seae  ;hitxtFrihhhiirlhKy hl;ytlehlolbbWadrgya e ua lce oieCw lteehoetdrtbn qdn oe:?  hnenr UouLatm hr;C ehhstsUooeu  eiengrghrdoeosoihfceelspedu  nee m t eyipo
# ----
# iteration 900 epoch 2 loss 3.412178
# ----
#   NtIotPwNoherr  erre  eromed rstceriII.,tob  se  ohewurVs ipeiedihdonmrtoVsqPrieic  EA.adaertl.Cro l ah rarrf rf nnt sIusvBroetNhou bvy eeangIIiaonds :fuAtdbat ohyhasrehi wttpo id,sfugamc ncoa  dnhlai
# ----
# iteration 1000 epoch 2 loss 3.355774
# ----
#   ,p,o,wlbtorkapart fdhonaet ns t,b sKeecnu oscdhoKiRawtemaorn tniocot  i d tbeceshm:Evtra mlayteruy poh:oO tk o i Fyi dey' eo?uirisTt:on ,hmeOdnfosfehwbs:  ro tgweser sNas:o,o tnrs,t o ahoe hlrk nents
# ----
# epoch  3
# iteration 0 epoch 3 loss 3.266533
# ----
#  bsrifeebtlS guo Erh eNhBiei c Ne fmwTsoa Oh,nN,, .o.leyaglenAaw , l eewigoe.mgcFIy.l :rwco ' OA  WinA r!aitc Toy i.aoayn oiasowodia-tweAt:yteeA.hR oRNnA!o:aiA?nneenOTdyCleSmean aDoWhhl StOkci!rlhndlof
# ----
# iteration 100 epoch 3 loss 3.228828
# ----
#  oepha  all ou heyti hfddp ep atoft,ermedteeoTeaaso'tT ulmnTmoTtobnNestvomwiaee n elhtterefh,trh, :layeoInoy ihadepnertmatoEsmoaI mloaethl hl k os e-Hu ha:OrV  tbatIneir hesoaca i oebtiinaheutyyots twm
# ----
# iteration 200 epoch 3 loss 3.237332
# ----
#  uei rrb:gEginevHgor cid mhodre nssainaB  r etr ueh,bthheOgtttf  esuheeraIoves A w ah u mloot ersioyT:edmnoug,a treftio steb,rhonltnh eh CI ede nt  'am odTnifhls Nj  o.hngh,r ohM pvyr  ytsrvmKhveice td
# ----
# iteration 300 epoch 3 loss 3.160526
# ----
#  rebetEnarOhenUems tttneltdHetauhoKrhm, aitecno Hei.tntwsoo hnp :ioprvrwd ua,lY msoeIyfKntk oefedefr eanTotil odclroDo htncv opy psyHtbrgon cta fbnhh twofKe Mt', hA.vrfspt I;meocamoaeDs wYdla uiAnoet n
# ----
# iteration 400 epoch 3 loss 3.277429
# ----
#  o sary desahnihAleo p Nahrel  nhpyutygne oe w sn ecanm,?magnhrtrrri mwio,Faf u,hreafa admieawsSooky AieestawmtiRueminG orfs rmsK noegfi  raaposDeo ni ta h hpfci  e fttoiorAe ues t  a:ec a bopi teDyuRn
# ----
# iteration 500 epoch 3 loss 3.225915
# ----
#   estl eIwyletanhl dh,se b tht xmld olIouhwhne bplsoeoi    h oI frn  ,W sTbbs dootBmho  llioTnst a rnR  rous ckurghotytadst: teLatcbe:io t- ome lhme l e ean nTtpmoa  Inre f nlwuwitbhu,utzwtuscya  :tegn
# ----
# iteration 600 epoch 3 loss 3.181096
# ----
#  oedlee SnugoeagfnttArra hHtwALyay,ehs r,Kaohimiheul  lhaage-oyumld'Wrukottbc r oohcteiyrlNeviah. hntsgnioDeirhTabo:n eea  Eotn., ei swnefsrhr terem tntosotU ieo,lehsunoatdqetfet   yy ga  hOk gnlenyhte
# ----
# iteration 700 epoch 3 loss 3.275406
# ----
#    Ltsw g oiam-  hmaThiONyNiyUiwIye LnklddPo a; uHeeet Orlyhcmgteduhlasaa  iyssrhne'e  t o,.asdbtoEasiXroOsph  hnd Nn yebnme n:etSy sdr ordcne Irtuntlybiet e rr deahrwo aEiOhnIny oL:eoRneytfwCrlpr! nso
# ----
# iteration 800 epoch 3 loss 3.299739
# ----
#  ertr geolee ucrhcln SeoTwbresfea sob  me  ual pst tdusakgds oe uiuIrs w;osv haruldHlsiauohd oe ismui P poeelahhnusrn. khe eaoiet.h s a hthh iVehd iohmioibelnfoeieyav a seear sre-save ighdlsosot   sakt
# ----
# iteration 900 epoch 3 loss 3.412252
# ----
#  htsbap:yvradraeo K eKgyuelJdleesoktgaumanE ae cie  ; ateIrtltTn Dgafnu'nae. oI t:gtt  ovye ehtedDcelalnde :stneI  lgttaiaaeabua  mtuc ble,hSs   rv rrotoIaN os ie, ChbtTanrrnnko ewon C'hh. v i:Nt bfWf
# ----
# iteration 1000 epoch 3 loss 3.355740
# ----
#  a .eha n ,atDeyttYueRefiumn.n  yoanO hmmiannchao 'Eaysrhcpe,aaofss enitef'owe ce:OemWsloyea nubmtshstiwgnf fo O! a,iB ,fl yNS a'rne nhNdNoosmaaobfeee;mEnetkyw'vu BTe  eaennsatedy We.l shf o Toe aaefeh
# ----
# epoch  4
# iteration 0 epoch 4 loss 3.266530
# ----
#   GhR ia oeENiwI sWAwoReoSnIlrnwN vtohstoAkgSu tqaothu he'oAsvi.s: aAIwte :teolr'sauli   lonidh:elAotrt  smmmcM  S'ohfiaAfusiesseedrye smo,rlar.t!. tgAni:AwlIksknfa:A s Aoesnoacl ml Imc: rtisgEwhnfed;t
# ----
# iteration 100 epoch 4 loss 3.228888
# ----
#  tU amwnshsnroogoe o n.h!frseRaw ria ei peldghuastfOcolsti-peti NvhgvueC afr    ewhl lead'maoh f.notrs l ene ' tUBhlhsdti,h ,Ntas ty fn c lhmaetf aWaaccheheets aTm rtOiennniuoney s:aae    :t ,ut io t s
# ----
# iteration 200 epoch 4 loss 3.237351
# ----
#  dashtov  sttoruwBtieosbnttrTr heta ruoh w   hthaelo gl lge eav  ionnenlf r wncuoat oi mir'fcQsdt, tonhiv eG ernr rAoir  E,maet Ewi  a rp dlh ci o? S .eW,eo ie. fiaenvbi s eo,og r,!ulsrb,tnhcd?y r::hhu
# ----
# iteration 300 epoch 4 loss 3.160532
# ----
#   lsleagc'Ue  ehomncbtssat !kaiip lll g: eeGrhod wlhIepHnr, r u fidttbrh ,ytid,neelmitI:E;rfore hfadyb strhomleKco Iph cawmt ohTYDtotrkahI omprrhWeeohdet   ief sio crrITfiaeoorr  ognseetiear be anrfrna
# ----
# iteration 400 epoch 4 loss 3.277333
# ----
#  u eo  ivy  ntedS t paoN rws,ore e n'tuauhfler  cs'nengbstp isnnol oy  h reastofwfulishnlridaakasg ci y Ore:hrsESnghfyne  h  edi-Eee h  m ul uuk n  lotrev ynnRpstedt,y  de wea hcRamra tA oyfunbunUst at
# ----
# iteration 500 epoch 4 loss 3.225934
# ----
#   pe sO Idcein d mhrr   pvOhc  ateReutn i,Rl ea.rsf dos,hoswe.bti :aptenbn-moor sasrto tiel oi  ;  iourestak:eultLmhteyuan,mmVoh?itiey:leh , tou !nwnbhb aner   gsshAvs e eoddohehit rmlt,slluihlhie,ttay
# ----
# iteration 600 epoch 4 loss 3.181104
# ----
#  rwesh,o   t twvuunenEutu ett  ud,t WtlAetegc mg: dihtafha flnosge   vttijldnyaodsc hos a ggerkirs nedmdw gnfleno hYeesY unt oihks Rgmhoue Kcohtrm  fCrtnnoiaggticmhrteaWhhfefnpo am  hrr h.,eeIlutgt  yg
# ----
# iteration 700 epoch 4 loss 3.275393
# ----
#  fenlep eumdlest m!co  dguc  Egfl.h s linc'hlgde du yortushCo   tiohrnaradothmiwaNrtieeaLmef:! hd,woitie?g tytndnto bhy EcytupyayhC so e yal.ese tahtfhs eiao r;m,,tS:riwsswtvh?hefi   y.TEedHT,cIco vqvh
# ----
# iteration 800 epoch 4 loss 3.299745
# ----
#  eneedensse  ynti oaceasl iliLieomhtrnhaw  idn r hM titiagrufhfdterar fAiZe anohwg  goiutslguyesefsnoou l aah neclamhsb  f Haa so,u  tosalochLs  tNt.nearss hLkldetoyo iatsminwtTdTeiadhBflo, e sNgk bsoh
# ----
# iteration 900 epoch 4 loss 3.412202
# ----
#  eE tNEI. .b errvt.eernsTt ifEfc 'rrta  nK,htpo,iM tiiArtabachoCase:g otpEeu .senhtg anao y oteC dh reaedosmb ;cnt dune:y yv, rraemri srp hyee yfasS.auascIeIe w oN y msrhsh aEp:n  Etht  o': w wieewNr o
# ----
# iteration 1000 epoch 4 loss 3.355742
# ----
#  riotdolr s  ei s, pavote futkByernfds, hkhHleks,tofrI ns eimtrefodo BromsntlhA;troNmb oniokoirmeo-elbs  mahaiy: p,.oefmn swu 'ias,Sr' aetpuum lwr oty?e yo,.a sklBhr,ees ENtP  ht hs s,rl'ooC  mihCrt ns
# ----
# epoch  5
# iteration 0 epoch 5 loss 3.266539
# ----
#  beslotmS Wf dPSt trt oThaAehi:n:a OtsPt A t r orNeueIODwste  o.iuoowvbntronbNneiRlrs rTAaItOolhl i DnS r o bnImpuaAStU a prmu irak nl AelT M t' u hw.kusrailte  gli lbophoi t tcsdmu TOs Do nmsepsenilht
# ----
# iteration 100 epoch 5 loss 3.228906
# ----
#  -rs ,t -ure  oiya aaoa taa tna semefbShny.eae hwric ,,ltur,nnnma , etneoseenns  nyd:Setwa slc ouhe paeceuote oefhtt shrtssyotlaeiuieC esleiaaer.rtteekN:ns eet s a ry adwtty ata h-ea s nho MaueIm g  lc
# ----
# iteration 200 epoch 5 loss 3.237356
# ----
#  ea,aisesvreaooaltr b ntbiro :heIdhivhtT nc-ahitauSemurdoaltCyoIw ue p.op?a em limrAserwr htna ccorn?l, wci,ewwos.r Ire . upos ;iA doterktvs ieihaaftcde i msSiekanCain:ho naon e t i;gt   ao  htwn, fep
# ----
# iteration 300 epoch 5 loss 3.160516
# ----
#  ritir reortGydu wotesnooeo vratt ,wrmIvaDia n;rauirsoeTmt?rlS?IO rsi uregtoylmcyeGfntho w ns tnWhttoefereqtRrmSe ayao nleCfssap ee ylhh I  lwalMie:onecS yaUiitU esnaInouu:eGgDleKS ls   ,,sa i:REh,ghea
# ----
# iteration 400 epoch 5 loss 3.277327
# ----
#  errRRe ouedtpeGUsy lt a inwteohO tces LeusT dotildnT, secr  tuit eouj MawIitia .vye: enlsa oefwlot eod a   hautm'ttD,?niigJdl,:uhG soerE aLhYeGStiwnK Reo ik tftdklpKh,en LlrIeShthne:ceNsne teedod:,ltl
# ----
# iteration 500 epoch 5 loss 3.225939
# ----
#   on bta,hddwT.-IoieoasCdho shlfw c,cg.s'Irkh Ladienw   UiaestOs tawd,lhaeda,Ecu sjoyo! smcnne.mee,  andil. laee niRohiO rhmdltnM hmnneer mJHmd eh uuenahe mluoaer cgWm, Arr,oM  omhentAao  mUasgtslhiel
# ----
# iteration 600 epoch 5 loss 3.181110
# ----
#  lOe outsrgmfDdIah ewoo'h hwocnmdeyhd twDeoHtoeoeyd   bislAbida e rorsetot wr s rhDyal  louaaMhnthsLrtsWmtnvde s rl yapudadesy  et'sdTdWephie lw hie o' Hnwbyi eh wIoseirnkorrnt o Ftlshhhy hdn t ,irsebg
# ----
# iteration 700 epoch 5 loss 3.275388
# ----
#   bNG?oo'dd ,'de;es Wdaeh iasgIdo,sythleyimtye:v? n, uineyhane M ny'ecs  nl l'rnoik'o 'roy OpleoD c iiue rd tpSlMef ahdasoi rusu:meE ones  gooat'g;s I.hen mb I,s y tr  osedieeslocr;Ot i'gp t ,Iraou acA
# ----
# iteration 800 epoch 5 loss 3.299743
# ----
#  nhhrias,.,nonntmoeem ktelyrts huoU p ia r  dwaee trenany :U ns Iawi lLoosol n  g  rpftme as vi seitehP  eCe alee beeo  ocott tiiAlplmeghyst  she,go erueeoIirCplesas bstnr serhaet h Tegb odarne tatih a
# ----
# iteration 900 epoch 5 loss 3.412199
# ----
#  co oiiylhsnsno:o taveVeste urLreran treniKaeantCofyaSflE mhpltfrf wes  Crotam BE  ch;owlt  fedroh.,:,noikssO ,cdD;ihrsov.patarafm aiUw  coenn u nlfpCoaisna d,w?:uieoya myhtOld oue evotwtt:hutfoYrt .ro
# ----
# iteration 1000 epoch 5 loss 3.355742
# ----
#  dutr: dteesq et icadsSt A:openlraLo chIia tia esdbta?sosnoin nEdrmmst a.eAtIi itneh y:rd aereetReowhplp  INtdeyBoasbwctp ooKeues p ema Rt:,otnroe tm  no:rgoeetecsALloaes caNiy  alhooeefigtttirossiRFre
# ----
# epoch  6
# iteration 0 epoch 6 loss 3.266541
# ----
#  :vciztmie. eetual irad ,ayN ;noaiu ty ddyoe   wesh awnpnowue l  stu t.eles lB ak osyAtHNnybec:l'd wof'bismBttflaemhoeh,A wAa ohnldelv.a .lrWiol AaBeahTnSIu uRSnPrWrlseiihkgusaATdm oe aalsemeoly,oecho:
# ----
# iteration 100 epoch 6 loss 3.228911
# ----
#  d rhnwIHeiepoethotS tpi . w nletnfNtl iar t -Crsie s,eaiueMnder  sbiyaesglhuo ak :mY Mb yaiena rtYr ' eoetc lsht  ochtgnayeiAiincotaNnhgr inh.o,p sciewB p ae oforscaa'htieutUb lhd eee nute:yyatShacyot
# ----
# iteration 200 epoch 6 loss 3.237359
# ----
#  eehhuer yaATleh ;auuh!imarhot?eee  k am fh A m  f ag:Ksdrreo gm h,antSeuondArTaltkif esdn ho e odnyed  hh;Kgd Ne eepA loh ''ddMiepwld  etie,no  olD  pongyesliehuhod hos esi O,trs  Rurnn' o  gGI ,kdsti
# ----
# iteration 300 epoch 6 loss 3.160511
# ----
#  tudhieanlei:lemnnf eendamnfoohae RaIdih ebneae hceesML!,o,calll,  inmh l ,aobr tvh ent uy  ilts medenimibrtoSg.esTh i theonesEooimrtodmE  aHenoyGtoact? d d oa rnsto  dt ByK t 'mw:-eknndruneeomprHatfa
# ----
# iteration 400 epoch 6 loss 3.277325
# ----
#  oo h tNsfditn nytudeinrysr uoeaiTns nabeueIopwoptu r sykviad dUh ,dlOyAerte sewsEOdyEh nuAdNad  sd t  nl lsnieimEAnlrodu r r   e nuaah llo sr chf  nee ,ae i,mSueL ofhl,er u it,lsonLl,rsahdlIaovieoe  s
# ----
# iteration 500 epoch 6 loss 3.225941
# ----
#  hT ii h,tuodn,aeoenx dhbbcbu:L; 'ttdtnUeiTSa Lo aRLChiitlteoaihi -totlfaerE'ezist   h o, n uyo  i:f e oeh ee'gya h  eo,oeu sdTarleeeeGldsMrhleetdoeaerehnroadw,ktO ,ohM d ,  btik lotsleiii rluio fbtu o
# ----
# iteration 600 epoch 6 loss 3.181113
# ----
#  oao Uuosiacisgsm md-tb Jr  ocoRtuCtr a wlaeirNthcdtehdrr'e  d nodwltsytDo,rftdnyoAuaoaoiyw, go r aWh tofohtrtIt egrehhda t,yhrrrihfdoh esn,wwspnarfsA le .nahb o ohihedt aptb.wwdfeghoha rdpso RichitMrD
# ----
# iteration 700 epoch 6 loss 3.275385
# ----
#  eyon k mf ri  b,yr h,lr,hfln e, E senN Ib  m l,mic'cr hi  'di lbeQec rh,e eoe rCUu e el triEi EnerpIRucstvchGoNocnbetTElmLwytksfttdee cuo,Hw,siaeaaceMypbBa fs us,urtwadpo.Hhfi guh.Tt,sa  Votawm 'ineN
# ----
# iteration 800 epoch 6 loss 3.299742
# ----
#  dOteocni dghhysaarufl:lnreh m avOa aa el'rys  rdsri  eh.h sinse  o aeaear  sut oiesha,aott ho ooUe:aeeoe Oahuogb sre r h ttfhntaeaehclot ir heewe?oaanAe ls ,isrh CLr alas?hEeocbe  Pwdr a   ktsyr Ieo g
# ----
# iteration 900 epoch 6 loss 3.412198
# ----
#  h coepPcxEoedh.iv e nio oCn hrItots rh.aUueI searh. o,h e yaueoyo usettysutfowor hrego eswymarshnc uhoeckCoase  T:pi ,osAuvsenmhiwndtu Lunni d a ?  t; itpx gsPlafahneoes eo nt lnfoee v: avpcdonygritEb
# ----
# iteration 1000 epoch 6 loss 3.355742
# ----
#  jbaeza  eotc.oVc.YgaStMt:oeri,emth;hrsauRAhteeOn nobE  t e   ishIlemgo:mr rha rttithc  , ?ri  w TyIadhyr omtioR eueiuy s  o,yK edzots Bionho an: iasymuv tr stal,oeoiu.h:aeI xo i ip,wuit ynhTeilOtar c
# ----
# epoch  7
# iteration 0 epoch 7 loss 3.266541
# ----
#  seietg nll A,l  erhWl ' tAso.nsds aoOu u.efsawhlarAyDheh.u ceirnim,m io sovo ctesps  ikow hecNriNuo.d rt i rhen , aooras:DrkbeO FfoItonTnIbsano   mguihloowOt,tTf'O'nyfleaSASeeAa O trpc;npr;ujs  enei E
# ----
# iteration 100 epoch 7 loss 3.228914
# ----
#  wds nE   cs nW.lc ?aai  hlsSCeahd ausLi ha,nyt Oeeuy y gNdyrnehr  cumom eOt !stlO::   tey,e bonfi mhneaupaaoscot;i:Hu r ao otoh Np  trvrg waa t h IoLohilrTi neuencoeemmcyrL',dItIuR; gNIaglwt he eErSee
# ----
# iteration 200 epoch 7 loss 3.237359
# ----
#  hnsaaeei,yeom r  toeoC son!sno !aeOsthttstlros  eae etynkhuhodsnso t,wlu bhte:o-uvle e rftux.snr Toolyn'eeteegt  Yirnsi Ttyau,eSwrolTurureG,ansency h dewlei hBoA sn rchr ,:tf .hiee ,t Uwdl bmrdst:s  t
# ----
# iteration 300 epoch 7 loss 3.160508
# ----
#  ::hudghoBroWNRyKD Rdf ehif  n,hyCa srisNetoCr tes  cI i rRaureeno oyoonsd,,eno osnnR is, tnm N,dfNh. oAu whioeagr?i,trlgi GrFcTrth ttoyha tehptdze  rTdsslshlon'AmmNaihDh o .tRnshseSthne lt  sotIRA oI
# ----
# iteration 400 epoch 7 loss 3.277324
# ----
#    gdRotn wdefaw e diSrlbotetoieo n seth fml'AaN  owa;goR ou a tmE ts wr tj eyce ! ihe RIoulpiinwgtf a rw slerajtonpfa ns,td tgp: tE  t drrAr:   rbruseo udUdosrirn.ruN naos aao'ehctomBb,yo runlmeahhdot
# ----
# iteration 500 epoch 7 loss 3.225941
# ----
#  siah,tgpftl   sadm r nn b nmhm! inl    aane oti,ta.eu oM  n oie yohe gWsnrieolacrOoaN dUdluealLawelTl maPrsrye,hIv,cht ee ics h ed  lea  Nmiuh c bRovoeNedtw ci :  UttbmRllet ed .of c ir.enorri a oe
# ----
# iteration 600 epoch 7 loss 3.181115
# ----
#  N  dycs?yfWfgoswplotsiathsh AneshLrfiori !khhdtrewuurt,fAuyu e, gemt rsl? samwurtmotnnlsch l e   h o.oes otdsh whtdtnglalrm  ioo bson Cthcibft tgfkeipis'h IatfvotEFiyFn AHt  cr talraohhsrs,dsod weeeot
# ----
# iteration 700 epoch 7 loss 3.275384
# ----
#  c i ,dat o  trsulofipbpefosuecsusi es oktii m i lrTu t R oinanGarmin'  tukfmoayyvi scadsyysF:i  owt.neaw dwoTot tpohalti e  atego m!eoeayg,f owheeHtoltoIddhep,ts   i by hnO te yt;  wtin:nn,dohcor!b  e
# ----
# iteration 800 epoch 7 loss 3.299742
# ----
#  i ,a,.art t sendlo  nnhu li  lvalihiLedshfp oKAtfeAoeuhoht o' ,oicbt iwBslAyer tamLtA  gfto tn.t yloiimwo  t i maTIronbn'fe hselaO 'sydtc    tsmi  yrehaRs lis nbmstTd dinay:e: al idmhl'pNd:ee waerLfo
# ----
# iteration 900 epoch 7 loss 3.412197
# ----
#  c arofvh i emo reksrubtsdeA foss    pN toUlyvs: itesalc ud   r r,enQlahifrgNv e'rrr lhmy Ba yCcs.is aBooioe :nss vv hs,rr:sux Vn n seted:neu   Pa a m;   enrny mcyte d DIpEl: nOrhty  'hr mh y kH Ndrmed
# ----
# iteration 1000 epoch 7 loss 3.355742
# ----
#    o   lvehgreyotcacIteldrueudntRmoohamatc TeyeebwadecLlctaoNeymohmaudr whNrur, es, eHlhBitt:tonbhmhtgntom f ekeaoA t cthssaies t,F ahttTeitrb sRh  v.Aaea tnre t mKo m T  tdseh uoo fre wn sr n ye  eei
# ----
# epoch  8
# iteration 0 epoch 8 loss 3.266542
# ----
#  l evurohaaor r raAt;ustDhhIcmS hamaa:ehinfwLtko wR!yAie otothadDIevUfAu  eAA omnv  esdek  nnTroseOmS er ad :Coe .bnwwlgsTlei teeBshseh a al!Nu iWoMner nAael seemiwselu ri ined i:W oAauynJmgn,hr tuasl
# ----
# iteration 100 epoch 8 loss 3.228914
# ----
#  dtn'thE nnSeonsehmiy y ae perIye:hayoa  i:dwMghWri MmhoRc actene oonfaottn synhan hqeblU  W tme e.fror,uhtNasheustepr nSotA r eoNi fsei  hdSIrmsN!asan borC ltoty:arB iaaeoIo BeBea he e hai un.uc m   O
# ----
# iteration 200 epoch 8 loss 3.237360
# ----
#   rh ,nwtse Mi E,UTwohn d ,a i vI Gidh   c,aoi keuteii e TaaaotC?s e  titCCoimro lh tiargredsercbudnuoseorIelaevoofgoat i,d mre Rh haNvr ,,ytwl lor lj  taela ul   i  adsen teo,tnr w,LuEneo etr ygss   a
# ----
# iteration 300 epoch 8 loss 3.160507
# ----
#  TIRiows s nEos wmo; r i.ef   gpm le leelmruLl Lseyeo hiLel lalots  bo eaI   ero dnohSsodiethrhi ode qpe,a f vlrHhytio? eG  Gnlmee  fraNd yrKmhi f.  dnnT toIefeeuIrewetwWi  qtyDim  oydcr cu  edghemrriu
# ----
# iteration 400 epoch 8 loss 3.277324
# ----
#  Osdsoo,irIvdtdCtyi dsos yasrret :  urmh aedn ewaphes o,Eg hfeimerisernbiaatssnmsaD, chEl h,ef bTDeee r aI KcoaAhttir agrowhtltgpb oyhw fetl  dfmw ha.o,kfvrRes t  ere,   fewe e  hell ei E   pegr  tou n
# ----
# iteration 500 epoch 8 loss 3.225941
# ----
#  wcJ l ietBt'ma mvtrymIhhd eyd tl  lA hii.ihrivnFe wnd  Ii mdEtabecm?ddrRhSyfdt ie Ioee ehrA  bha,wn r.l oaWidhi dio cunttidiu!uoyf.,mtfThntafw Rut:re oAle yyns unawTOjw km  sl ' iihE; T etMam  des t,d
# ----
# iteration 600 epoch 8 loss 3.181115
# ----
#  fiaanidnoimdnohonegednat m i, tbnTBtortntdTA , md doehr edlansoe pPOYauW otteDlouamwk r tYlhhBl  sehrhthuai fnhA?  hrihRho onr humath g  toa Latado shdet ntair.qe 'aeuybhvn  rT  n:,ier  Cea;rutF.ognri
# ----
# iteration 700 epoch 8 loss 3.275384
# ----
#  rpoo a  ee  roun:yaeeTstl pme:tAtllr stu lefvepNNle:dthR oetmiTaoeoeNeealhaIteLkv 'itmeT  o e-sg se teslanwudmhrcrwhneAieuydistadnyIrmnmnot,d  Keen,etF eGtgnEeyIaAeO uro  tyaerfo cint?t isE  dcn delce
# ----
# iteration 800 epoch 8 loss 3.299742
# ----
#  ul.oa tdato mgheSWseed tnehhe relc hfett uFmMDkots rlheWkoeerReet,u I hdoyratcoNadsm  myH  D itehsli  RP ble,sib'lrd:ddDhdru'tubonoksT dhmshim  emes Ruoorii ,looi  lrto lo l  f sn suTbS,ahaa, esDs  wr
# ----
# iteration 900 epoch 8 loss 3.412198
# ----
#   hK  nenvwAovrUanTe tbSeha:ar tolaa au Cvse'yatfenrmarcyougow  sinCrrNodewloeon.weIRyndevytdOlNy,ta eamrr: ,d Vn?s  i:' , ar  sntc pw.ovh nptKoe?esaC s:Cath o wreeel,r oshdia ecoWy h vo iTK  eeolh?a
# ----
# iteration 1000 epoch 8 loss 3.355742
# ----
#  poA ?rTr soour emn   BnOe!e   a;tfaseeayP,ch teiselh gc h.Hhdo:rmIheekH  spa cutinmtofhairoooa p  nm hwmdaahoKweh:aeuit'cnvan eo  fhfaafc  rarch, T dIteosda'b l dTlwra; r,tud bNbwmomnuKsao,meUfomO p.r
# ----
# epoch  9
# iteration 0 epoch 9 loss 3.266542
# ----
#  tohsg musheR,nBl trOhrtvh nlt incdlevre,RA . oeo:lrgobnO:it  tpR  rcIs oWaneerhot  esbd Ake: oe nmtl'Leooal S bo roiw'STwWA ostnttn y Og ireoAdiabnehaftsseR Sahfe Teo nm licS Sugoa,hklw,a ytA ohTSo!ae
# ----
# iteration 100 epoch 9 loss 3.228914
# ----
#   ew h te yauelw, dsylll breupe e ro sy,oe  noilefTo sa dyet as  tanIasaeh  hea a vy oUEovx   amsasteTolnmeHiIhtix sslhor ttcse on loilooge l eh Ist-hCooymgehmynmt  rna hidooere.ulet tdhye' oosI r be t
# ----
# iteration 200 epoch 9 loss 3.237360
# ----
#  orheCn  se'ogWir a dgSmi ayoBM li nue,inn t mgUyiririwamodsviHftoesrhlrisR nnwiuyt y'Stnai iftle c.oin om rpBilGndr:  edmvrtgne smp  r r ucddnao,sredbnrnmt.hiaGdllMe tf:rea aaAs.lislnrIytstowunSuaeaiI
# ----
# iteration 300 epoch 9 loss 3.160507
# ----
#   rt aats ag mfIyOtTwaimstcboo:tahkmmlieopnn y oeUtHd  IIeKrhcerodentvere-oaism-rkoSvilr  gdoom daumlafofa  Eyne R maltdfl e iedMtfnsaya owu  odum  ottsvosa a ;eeoAOms rrl eumtm  f igWgh,rrHbcHf oeafdd
# ----
# iteration 400 epoch 9 loss 3.277324
# ----
#  kld a uei rft aeldahf,m Nutttti imeNdr,Lwroepiolu I ry iehne cyldk,hIroasnkereaonahAnbfliAwtid rn dI,wat d hctsnab; eaihiWdyo, gdftfhhwchony,s d dlEahtsl festisroh rgti eeemeiRrh ttoe  ef y,o ml  tr m
# ----
# iteration 500 epoch 9 loss 3.225941
# ----
#  bt:ncet hihs:re hlh-to,bIldnsRTcM -awr so,l?ttiycynmodtrbhT nhadeoTt,U somultltnl  fTotpTai etnnieyfiec ,t  ae R ufm  syt gltTaoon s  uereo i i  nRey!dMi bd tlwCetFtw h fd ntlrJtnntie toic v u uheilha
# ----
# iteration 600 epoch 9 loss 3.181116
# ----
#   h o'ctooe rio'lm etw fgkirsn lkgun'fy n sd?, r dubgchscdcklahnrssqrlsenoonun oatOltwoR,h  'yhtu oh  oasoe febtu oueainmagfiikwiy tua  edmeu oess r dn t  gbA Rooo emlhy,stseeM o aleko!lefultlrhAi',  o
# ----
# iteration 700 epoch 9 loss 3.275384
# ----
#  us.s'o  euNs ise dtCn i ytaeeqaY   p unriruwhtteee :eVyownfdert,r o dVhems ucsppn sint rLgtnlEinlaaavii ; eetic,Msm ye lenwd bdtftryy h  uobEmcsnIi?iAE t'ge No,Allnalc  nbiooAI' Ite oscri:f' oiiiemui
# ----
# iteration 800 epoch 9 loss 3.299742
# ----
#  f ofndk twTl  uruReb ehse npcat,hrlnb leho vhntoSr, Li uem   q sGtur auomdbhlgunaeo ,tso e   t  ntetlei:in,  roiersheee.udeesosio reete.bohi hketi ib cwAganelir eaeessph.euIodshaAotseceummsesosBI,idd
# ----
# iteration 900 epoch 9 loss 3.412197
# ----
#  t. ooihOlr tok lrouhoeiKmei.fti  ono:eCydsyhpdiut o Ip oh:d ewe oit prhs cr,oh o i uewytInt nredf,Wkodtr  T!hk rio Enhafble rvIt oidhdBal younrcndnaonoc erui ortrfrsd? Nhrd aufdfeurtRt csb a eniTbut a
# ----
# iteration 1000 epoch 9 loss 3.355742
# ----
#  mah,eJ:leyuywumsos?t: rolwB  Pwlr? d aNvaihl ka ocouml Te be mbtbdUehes hYho  tecstIea  .etod.  oo;oA-.h  wgr snio a t heOho loThn ,:  'vo iei r :tAm skmtset  doagIOdh t gmdd ,pPteeasmlttaa  rargh   r
# ----
# epoch  10
# iteration 0 epoch 10 loss 3.266542
# ----
#   :hOmhITAOd AurAOatn ahOnofUOdos Mt fers m a eee,oOyhtspntasar-  n kte!.e:Slaakw,sFlgmathva an.sss luie orofIertaOtd,ldii:t  oydhrioarwlpemtvneidwns am deRr Ah rehfEtyNeblh-o mwo.ethw SrNat geyny ermn
# ----
# iteration 100 epoch 10 loss 3.228914
# ----
#  ooei oNnsUhle Sto  tg omw krUeare,em,t e nt  osOiutom eo re iseu cI aetcmttsnR aAaChOii ireiheee  ein h rwiudIamefdy aIehdemssmvu,iea dt,etSrNh Guean et,T eaedls t  hsYCcoth.i oy.,haedpe ytu:vheha,:dm
# ----
# iteration 200 epoch 10 loss 3.237359
# ----
#  eoVylg coU oTsdeR sfut ouommhlbfunot Rl,ma' tye d nark snt dsiiwdu dw s Hmilya e r u  t  t nC a Cddla;g,rm  elardih,W - hLnr o    estmm w tu,phkitta rra vi uqahic, c uuoaydc nlw hfs o s lrydhRh'voti m
# ----
# iteration 300 epoch 10 loss 3.160507
# ----
#  sRn sdi?syf  :fP,e nrtGYof w oSiMtra elehsyu udg aohbS oylehMb  .y ,erd nsafrn  ,einath'eh R , totato  R rsr'ngsttoonnYNssKr irolehehy use:, L mhaTnaw t.iD  d:I t,ktA:uKahatrStfh  weneln d t  awkth: !
# ----
# iteration 400 epoch 10 loss 3.277324
# ----
#  uib tAfnl heLhh hefte s etIkn  ar L op ;d,IiTnkpas unmr  gejhewleA sieam    L  R  U,R mo   e l G lu e tdgirt oaw a mdta itollaef f o,tI,eOealsl rS ywkrc rlhynollds oeiIpacios din   itJe noaie :erokH n
# ----
# iteration 500 epoch 10 loss 3.225941
# ----
#  benb YltatRb!Oen ap  enyr   :eyneao Osotd' kclhbat ns ertsyebcw oecoTe aa f fs mmOtrsoraib uhtyua hh n ea iO rey,,toc    re'urol tineEdcekatnaft,syadm hVa SFhwetli OtIte  n  il l hmaeeoI.uoh engayr mo
# ----
# iteration 600 epoch 10 loss 3.181116
# ----
#   ht!  gth enslhr h: awYggtaoeosphrilh ai avd tEhtld;tao,nue dehp en'c,foAieop sbnwdntsehta,nskth :nnYnld aMeh o eeet  clmae e'i Iar  fddaiQfost  erglsrAanLtu:iR ugdiAGuusuRp ebo so.ctttoeMhn n k nNahe
# ----
# iteration 700 epoch 10 loss 3.275384
# ----
#  afbify  lIeltts kthsaoa O,obepth oa elo didiksfNieot:d l iy Oyoppo r,yaI,UrSnoa usstnnaw I itad' bih t  opd sWorh'evsysth.toLhsalI:dyteyyR:IH wtTasddainre' fyrrdkrtl dr ngsdattyrIfLD amohtTlb lovs:Lpl
# ----
# iteration 800 epoch 10 loss 3.299742
# ----
#  bnnSehts aummehtehhii row  damUehbtrdbyeeauad  ehn,easziyr fru dskvyuIh  dhanhHoddsl'noho rebd h  ,ekntntdedopaXhb d 'nomeg,lcrorN,lr   t rihnn'eeo,tsieThoeloloynMyy krClelsr y wac yi yd aefeaN eila s
# ----
# iteration 900 epoch 10 loss 3.412197
# ----
#  !rnsl sel'rfv etwn  r C ui   daoaonsl iaToiilnnOilseh?etidepu Ie neaonri a Aw  ss r.eCwesrOa lprs sd teoleffs dHewgebcy  ur,fWgyoiono olsNnn dWou c  t, h!vhse amyap.hyo pdUn nildsior  ernswlENetetarym
# ----
# iteration 1000 epoch 10 loss 3.355742
# ----
#   hotdamhwohius,ye nera,macte'tteeao oohtar?crNEbanelFoetAo o    o ertfdohoIoen eieoade; l phnh  btngmmomr OK:I Ghtly'stml IseIaucdrto enss msthyea oeesges wsLtWRd uAo, dmBbNhIts..br horRo i s aota cot
# ----
# epoch  11
# iteration 0 epoch 11 loss 3.266542
# ----
#  Oed hsLAoccS g,Ase.t t!.he  nuEreerd ltIahNyrFF r AdrTimIotLAlastaDsee ohea aegrossoNalAwaOesv! ch OdmS:b'ob N hanrwIeo caeN , o gle Is yammOn a ate AeoOeed gsbi ipmoo uAiro t Ay: y.hb  mtdti  on:eaeT
# ----
# iteration 100 epoch 11 loss 3.228915
# ----
#   oyO tRday n b nfstnt   syek pmaebnLhsoagueee ae;n reacumN:  mwbr soI rSie,a  vatygritpkgds:uee 'dm p, kteL ksrI!yhphtit W tt poedhih uyame r L n a tuu Inhoeaihs.l ierdd'onaam,lioovoN,y noAiam, e v he
# ----
# iteration 200 epoch 11 loss 3.237360
# ----
#  shf,tahffd nbI seuwaoiwteohet:Ntrolhehi,oensri oIeneemseMaoesdsdaax rSuafmnah   w?knelak knsn; e  ie ?k  a    aeAnruric:hnhrto kdeboheieffd nge  mo  dslre  eeotywna ,e rd!:feo  h Vqs enaa rePp h aTd S
# ----
# iteration 300 epoch 11 loss 3.160507
# ----
#  UtiRI Anrtomrr,.mnhareKl laoRUuA,  e  stnn,I:rSu:nttbswniefIeBs glsdyM iolordes: 'er eg:dm  emeasseoi oet RnfGIeeo fm, hMheRuslfsGs nrni ,eoeecdrdotetot-lfr dm oIh,N gnrlnoioTeosffsl fWi a.tAytpow t d
# ----
# iteration 400 epoch 11 loss 3.277324
# ----
#  YomdfoynwotU oosTc,io' anahtenc  t syh idmBuoeoaw cshntotlFeoa nsnNt.bPpt'irdrr dd  s ShIcsTryhyftm.etmu tostu hrIo :lfrlit,b,tan;hts eehtr,emmS:pyteoccitct nt a ae i gduwnoaI,Dih ih hrB  rstdgp auriO
# ----
# iteration 500 epoch 11 loss 3.225941
# ----
#  vhsybuhw  r:n oe  lvttlisdh  fineatf Iea deaYnrcgy dl nt iomblns useeIlhr hdr nUAwhn:y  naog m'ni-w shty em,h ie tseeneboyhhs oooao ythh  mtairin! ygl T ico;slyh ai  dl CsOasodi, eu,ansa h Cpwadrr att
# ----
# iteration 600 epoch 11 loss 3.181116
# ----
#  f o  rgta oairsyatAtttt:teoormNuha ngnlshwrrdgi uD  acnoite  Eaa kLA  efClaioCl:goo ytfha heTaoU ni  adnsl ooiaws ypdsrifnyrCogtemysres  qhfj  seynt cnetteial s ollwvnar s ywuenos?eie  teloat  bTaekno
# ----
# iteration 700 epoch 11 loss 3.275384
# ----
#  essg  ts  gnhunheea ichrEe h  EfaacditueogaIhttekha Y, ,RfYeleind ehhhbu h iyo dagenla norkhdvnE Bs  oObrVmealloeerTpan oE'Dsenee hmlAgn emkeTolsKL deTAte o, rEiswailotrlpT'm,oiN r yutuieripShw ll npi
# ----
# iteration 800 epoch 11 loss 3.299742
# ----
#  Zhf haMes, ,lnir e bnh umb' !nh tero a liftov sudnghb rafrtia:Tegee styhdi e wfss  oa nleadnf uTrSoelwiumei hpmeesd,sU?batyomorabd'res hgsUeradi , toa sellnwvk i,awoto rtainnsRvt  aredt ngdoiwaiowt
# ----
# iteration 900 epoch 11 loss 3.412197
# ----
#  oEhra u :oNiec yvtvemsuoeeGar,sSfohieolrneg rmUVgfuaKeP'oWdraqIti tys,mdoadr u truu, oo  en fth vtrylihrbe:ns ita ooeapnIrcaeoyos wrO-ehIs oay .nogolbdr'eee o?fbr hlntnaroee N  ec ms o nKyihI , eisstg
# ----
# iteration 1000 epoch 11 loss 3.355742
# ----
#  gb hIhmie  hwu wrwf  a  lo,  oisidtku,oinmo eai :ao d yrdysa Hr Annceiooreha t etahan,wsg  l  smso ha.uneondn emdliRsl iehln.armyybalobikgmkatT'neEttossNIteeorWaf awiiyliowheea idoy cwpnaetedia  'rb A
# ----
# epoch  12
# iteration 0 epoch 12 loss 3.266542
# ----
#  hahaB,m smAu?urLoOaOnPgsiardehNonuSsifs Tol tdmeetaetY mowesh:dwG-e?nNSmr, ymth d ogsntNa fros. reitr Nhiob'wIusn e IdtnuIsuestTeroh  hortyl  trfht ieOauo rS u eamSai ah u, gdetl a eno.n iTL,e  :'hatr
# ----
# iteration 100 epoch 12 loss 3.228915
# ----
#  thd iesenm obsov o sipiYaeS u:nem tt :rfhstCeniin  he, e  C'des ah,Ihe:et du o rLsn   Mrh soioeeouoage 'ualla mtfhp eha tten fa sdshc mIdmr  uh h adnoacwy rm  rsa.Swoers l tIesc.wasU osel el IosegheMe
# ----
# iteration 200 epoch 12 loss 3.237360
# ----
#   iRa,dehomse uiu oP nftoioeeRetMr  rea  yeto oit!oh!a Er  l  sy:Oi osiresios m  eymu  ysbnhtaquoo ry egawswrS,iHs A cei iennveren .usuo  ih.ege yeIooL: sEyiv aydserwpt,er Es    dW,uno oi u S u. rwhCGo
# ----
# iteration 300 epoch 12 loss 3.160507
# ----
#  CutlUet t Elfmtr deHa lWudio?m.oN efhyldlyc   oa tmoao oEahah rslrmf sihf grIuamd,nFon enti C ebhlihongT sF  stdR taHttiaeW gxsmt  sinyt  hrsehhAId ,sIoesaiK,dea lnid chAhfyt  tnoi?so oAnthtlNt-sN ea
# ----
# iteration 400 epoch 12 loss 3.277324
# ----
#  ao fumtes ouh ei wbdyfIeouloiRoauelatafn:todem?ea u ogeteosrae mres luy Dulolato aiFotos,osid n   .oe thdtttti ueeuet l he,w nfiedocttge oh sEhtm wpncnA  e  uo reoed BtI nseauyoriri fgto IaGa,itlrutwa
# ----
# iteration 500 epoch 12 loss 3.225941
# ----
#  tbseftsnuwsomb u brdeclbAo   ol e ow.  , bd matlupeli eOfbr,lol  ee  rkd's: aE ieowjOcsibmbTgneiardtdetwuaUecirrwtohntLaaTy etsqaWymtrTetrrh  hbulrss  g u J ba oym.rnbIa,boyh ydlVuTOptl i t,Rel  cokda
# ----
# iteration 600 epoch 12 loss 3.181116
# ----
#  guG tYc ns kh lypron  onsla uneedrF oni,rr lenroh foa oor'tsn reG onyy i  toearayeftro lnl isllet u adie hp cu Ierse.ueeFma!ionour'nie  wcaetsTioyei,Feeityuwuih aWg  rl:omfaivreiso aits oA hsty; i. i
# ----
# iteration 700 epoch 12 loss 3.275384
# ----
#  o eyrnlenuh .ia no  Omekmi noeoyatC ul eOtw e ue  Ih  d,  seeiOmaulahtefWM.a?feAymt nnonoh  olnewnm,a eTeEencX rsmi s  ep iNd'artnhef.nito ges rot nhulFfp nsnapmauuhesN tb  t'itrntmr necsiainspr.'inoe
# ----
# iteration 800 epoch 12 loss 3.299742
# ----
#   nI whrtler  t,na tlaTrht ylwt? hu rmshtu a  unee yhgs lsio leb-ioYvs Pith folodymnIp e,i oEkeebn'srefr Lsaryuil tcrnt  ai nsa:OehlwhRNesyLouaae etsutlan heL yeh nniestioletdy iyeuaTteeN sxsohdovnUssi
# ----
# iteration 900 epoch 12 loss 3.412197
# ----
#  rf: Gin:edloelovpfeasornyssmenpbal od; rkorwDdemUeedaepnvwaelo,e rhn iny emomv;Iaprhot oilsn  cygrew ilyi,Nu  ussr a fgs drodmtoweiCheesv nNusatIrntult UEiEgeetsmty:svhoann-lrldtsddratsp Ewyg:CnoocDeo
# ----
# iteration 1000 epoch 12 loss 3.355742
# ----
#  asllaltogOied nhlelsirrh  wsN ena,st;hamii  tritv resEhCoumwaao:TyadieF   heh mootel aehshtn ea yse;B etyepeo fNtrengflb   pecpocw ld oFs fhrntloe.s OiAeesrsfmoo e AdiameN mhe nimroy,ish h li wiheo SO
# ----
# epoch  13
# iteration 0 epoch 13 loss 3.266542
# ----
#  Ieowkdg AucOn,yoeiaObhOaOom T-sarLei riomSir aib oscs t 'ies,okOxlNdEAo' !Mhfutebram eh aelperBosRdinuiopcei  i' W e dooeanOhh rw  :epwn ieArvs,eomreeAnRNpmghhaO'TOlenlAoton;PisySO kshr-A,stW I I-edoh
# ----
# iteration 100 epoch 13 loss 3.228914
# ----
#  ar  ,Ns,Dd euii nIlartysr ste' revIon funIei htNy slwan Iaarnonlc NtidSmse sv aUa Si utnCea Ia cnIe :canfIdi hNurirhnnomasc   xWtoeam: Ahafeen shsA!L,s h so,!eo   twAmdlte m uoossThoE:  Rauystee  y et
# ----
# iteration 200 epoch 13 loss 3.237360
# ----
#  eoweb h rudioa esbEe lg  n, Wa ph cmceNb  ad;EwyIoen , esuliheaerhrtsi  h:mrea drckwentewhktateedfeh iSsCfm aorIeenu ne iuytrtnppotddki iEr , ih detf ,rabuhntohdt snro l rhAOpreomeotbeoeh  e rhZwe,pn
# ----
# iteration 300 epoch 13 loss 3.160507
# ----
#   iEreAl :oadTRaol elohyoarA e uhsdsebav'fe moTmloIrtootdu g ,;Guouilf fause n  mnnCuemir soIiRu aumernrfrsGj.gU sr urcuU  eRmrns,B rNl rpr. Wtooeeo m   yIstgo  nsodeooaL tnIorlg eH  ttsfW AtGlliLhaoab
# ----
# iteration 400 epoch 13 loss 3.277324
# ----
#  ofddcUnRnh:ro ssni:w tgcc,oaEuedytyt eslraa  wttouasnn me, r eheowe  eu :rvii n nyA oo Smak sl'anwUeieh hrhkD  u,ts Fnkss . yhdsti rl aO l vlatrnryAeigsedhi  ie n dterre;rRsIh dsovRrsee,llrdoiWkRree e
# ----
# iteration 500 epoch 13 loss 3.225941
# ----
#  n'ro,,am  bU  rwncrcaiossNain,t  mbdne!meta.nlonvta aofoT r e iinnbdtr tninWpfkbenssso tU t   nskltIaIaihtU ?e eimt,oembeeso,i uoARWre  ;h v i mCtaeiytuts aRynoth  , s  eeorfmdw BymdeFolIk htl htity
# ----
# iteration 600 epoch 13 loss 3.181116
# ----
#   vunl.ketpayC r prrn, nnuWfn altnrrngl,  hfnowhoonrregnowo rweggdiumne eaIcd  ru ?adelehiwtch e nnsts  niaerngnp s W esnFlOt entatrtt uNttpriskiteeotholri  utymoouAmo!.egaknRrre nmgrH esmohnh eent uNn
# ----
# iteration 700 epoch 13 loss 3.275384
# ----
#  Iad's iN naTt riue ntaa  h' lemodmdldeouhofllme stwdsdu iosOso oioenmdeeWihlsgrlOt ave stp  g tt oC neeo yurheoe oAeEr;ell o.i nieeotntnttthStla n oUengiEi hyyh:btest.iin,thwal'msaL eemrow mwEm,Iif T
# ----
# iteration 800 epoch 13 loss 3.299742
# ----
#  tatsSoIie inrAvoYYng A ohli So UihUo nuotwStt,,nemhY c.ssahteaIannywShyr;tNdwigouslaiglihirret,driaaie'l rW?rgs osofglht t :ntmdenrlgamlo aca,cthnwff 'j  hdr;ip euer;e  iia.fh p aeee,dWnpiEt ,B siismt
# ----
# iteration 900 epoch 13 loss 3.412197
# ----
#  t :oiopyssnE toeI   ,posist  oo eut,p onm :lp? NosIOndanrft seeh  yortblleh dhe  oiihc  uee ab w arlt ut eolmsnapofWbte:oh shrlrse snhtueamptISlirgtotaMb :h  eaaoa natus    oU ouO at dth  O eyniZhsilo
# ----
# iteration 1000 epoch 13 loss 3.355742
# ----
#  ht roji aetnyid Iluese,ebbmw,h IemAT,eoldu m yyaooosall'ap etoti teenPlsurPmdbar otaldt u wNeB ntEo it pdtesshdoIpc Pat sya iP ouAyo f   lnmpiByItoeieorhsft dhot: u tNgyve rwhAe ,ne eomgedlTeifo ,e h
# ----
# epoch  14
# iteration 0 epoch 14 loss 3.266541
# ----
#   uehtwm: s TenRe   y' e hrntvAtItLkwi.nN o ;tnAenNh:,: hfpsbeyoo:' lweAw  snvgT hdcloc..srI Nh SOuekirsTt p o,e s co rlRs f  qRa Oraduwh:TnGin iO ooluhrAnhweI iS  o;iyWee nae  r g  dyoneelaTedi,t  avt
# ----
# iteration 100 epoch 14 loss 3.228914
# ----
#  ro s omy,eiouylmeaeiormt.,oi ,ltamaacr m yd e eoUcewtneMn ycrtastMeirsraescecd htsece draan moiedrmow h,stdasi'is o l fnt drIm onTatpR  aTc YmSe utdWe uhnhuoumAyICni urf nd rLehh  esua aidser:sOm  in.
# ----
# iteration 200 epoch 14 loss 3.237360
# ----
#   nMdsinaefhp eorrlnwerty erlta metWolwomWj:de  eeege aVoSeroe   cdvagoclFei?li,Rw yI  EkapcSd :eoorwe,m rNlamhithgt   ooeeae.srose Oce l'ht!too elewn  d   ,nl ytbl ldd enfkeoov,op ii erdMm dae d Oaoed
# ----
# iteration 300 epoch 14 loss 3.160507
# ----
#  fudfis;m?okPartfhioou c,fgiltnefoofyulhaes  aefTh'ot lltec aogtVisttvlm fiEW nhdIt  meBn?ngIbueivehngdrodOnaHrsca huiehs a e iTslerA'dtos nca'mRrsw,CeteY rc olhnooiten dlSFdedhdhci ma tusC it  dCioGs
# ----
# iteration 400 epoch 14 loss 3.277323
# ----
#  lLl ,trrar ruaguhyhnmDA trena :.ottDie 'tlwtupa   ,eb  huoereae ,NftcReHfuddrte pn r:ag pinal ehw,oieo'ebMuhrwwtu nralLelie n,aedessrtiidh; rphtekaekd!lNiuy aw,ttnt emu   ejet LE h n eAdjoMe clee.,he,
# ----
# iteration 500 epoch 14 loss 3.225941
# ----
#  hharbmhtlsl JEiejdbelir  f lb en  vihT la teben o tdy toat'tb;hlnchhoihiil:t e uubLdt olrhesatts eyt Estrethantkauheea;doae oc t ;o yhdi.,I r?nsnesrsscehilhv, ;,i h h ,th,;;c ehomC rR i Mibr s Wasi en
# ----
# iteration 600 epoch 14 loss 3.181116
# ----
#  uugitrA dtonom lSh?:elu o onktadmailn reo  ata tkf a nayos,u'h eofior ePbdnhrtoAkM rars ia tt qbpehes fooeeDWloI etighhrieaah,gemeoagrnoAudw in inDug ' Hdhdagf hAafthn wiowYo r,fl mi e rhtrsrLhsariuli
# ----
# iteration 700 epoch 14 loss 3.275384
# ----
#  ta,p-ityoog fas,o t'i uyszby grW oppeps  hote t '!umm ui elIheo eeisshssdy'o cewelt :yu hR fO ybAaeynut  s dr wk.t:neahg GkeWmsoisHSctitiih't nl hoe lv  eLs erHtaogyyhse,msdmtnyfvy u a hdldo ai  Li'u'
# ----
# iteration 800 epoch 14 loss 3.299742
# ----
#  h pemds c dbakdes fNInwdmHOIinmssennsdt-lorityn'w m sg-u i o oLahi e-nen yihla v:totu fhoy ,fwo no hue o.lo flru r sI mare  g.shurmoaX bfott YEevE bu eiwludsao ndt d;ngodok ru:ehas re ln ttehotpe,d eh
# ----
# iteration 900 epoch 14 loss 3.412197
# ----
#  iKeekf rUdl ee i eytnintto epaslseuKf I,a:m f le gahhsud aeo lyrs IkpmoVsprieatx iEp  olriatR  rosrr h reht ErtegnKaomosvhomaassuey s  irwiyaetNp gtr w , iotm. Eso NedT,   oTC tcadhIrm mvnIt:eet tsh e
# ----
# iteration 1000 epoch 14 loss 3.355742
# ----
#  rhlropw erosmSineed oeh' smhns rfieAr u ;o  ,bc woygwtOt?ays,hfeaNr,od:tA e ,eelee ' . esarlt ehlddwrmh' w r  F heePo roi hGeh,estja isCbitfmm iu    ohitys  mu    aR sttiscwnbsPtsVao,l msBenB apo ae '
# ----
# epoch  15
# iteration 0 epoch 15 loss 3.266541
# ----
#  vltyatlIl;mtamsasnra.wm'gI awte   t nwruto  ic ! wTelh  pe!hba atnmsnNrehreaaeeI toeobsNO Meonut!clgelsdAbuioTbeaR!neso tt;AoAibSOnm:rytNI   n cs:GtnaeepctllAWtrhb AyetOuisf: e :OuynehnRKA'Ne l rDe:st
# ----
# iteration 100 epoch 15 loss 3.228914
# ----
#  IoVT:e , Moc   tror p p:f w aeo rtVwwess enLnadI leggswidw  ete wrhkeoao  i t tezD Su. eugt tatheeMle:n,bmtfildo  erlYsMAcoefdSwcc   utohthoysoal e ases oiiossuwdct uo cem  ygdClieeeoisgi ;I   eli,nui
# ----
# iteration 200 epoch 15 loss 3.237359
# ----
#  rwWarsodtt, 'oolvRaU etbntIhs eHds .rD a fe s eQ M,Sgiee;.;egs,acenersnideu errt ouelhilrw:denehtoau   htrf feloame tw't Yr sms l Mr gntuphrjeorFsscg oe nhlvWRrIT sshio,skuCe a Iefns ofmndfe;creussemd
# ----
# iteration 300 epoch 15 loss 3.160507
# ----
#  dTiyehm.gv hhgDhcybnyn:sNtoo,e:eiir FtoieNp  s   Gaea   l rtrm taraw test;fCtbuesee  ke'i iRCBls W o ofHobetit, Elfm geve s od:w ooostsmruuTe?e tr rlyinn?waRrrilga orrn lmfyneom emdof o doirefoBu fh'r
# ----
# iteration 400 epoch 15 loss 3.277324
# ----
#  e 'mn ca ai c,icosrc    ep a epsfnauoLsHnu .eree d datye rl wsl lcu IpynsKn Toassuyos ewwipK i li  oo t iAl   trote ,liw o  v t dhcndorlrtrta.blhannEwIr Mrhea yeriIdteoabUeeokteyo,dnlrf fteOwr t   l
# ----
# iteration 500 epoch 15 loss 3.225941
# ----
#  cc iwiig eostoif,k, keln ee, ,eanunrosNo  ihdtAh: stmRCtlei y seftfOu tfw teaefctasTl  wefrndf,ptiiahsO.ottseiciiomhtl'te lsmadeaa aLtaWhy;eepaI :tidr eielvmsJat,ssepnh hehe eh gosos wxthRe  ,onetatle
# ----
# iteration 600 epoch 15 loss 3.181116
# ----
#  lskrtn  nurotd  noiA  aeihiage sahcnrlrherrn?o ektNinelwrra nuhaoefg,euadIruhy sno skn el ili r,f hhkloTirp oaosum heelh :  aWk drtoahame,ct:mav gy fghh :ss taWewoiiane.,nmnguseuel yt!wgnolC ,ehg diol
# ----
# iteration 700 epoch 15 loss 3.275384
# ----
#  uoonnrr eemseklWalArgtn lay  uot,vhie h usAi ,,NemCoAeu  s.oeSvn T  nnSmyU ' on e-, h'lsehNheedda  ennsst .,Ol's ritsaiuei a,wmmenteehoT;mlOsrdosM  uuoMdlnelr S I  hln tstu kmtsy'Atos eewnppes  bt,tr,
# ----
# iteration 800 epoch 15 loss 3.299742
# ----
#   l; enh ts l akrhaitlh ,herbaeo dt igso dkf tp nCoe eeciniOsmornerw steof: hhrrauohe noyWoell ieem d:a io nohe  iruPh rFfesaO eh o 'htAa:eshrtlFAfhltafIo hI Crig Luoluml opNreMn ',rTw:vfey ohf os:nhte
# ----
# iteration 900 epoch 15 loss 3.412197
# ----
#  e rm?drxtoarnD rih.nygbneDTm,t fCAerat . l eN sig Ebacer cVvttrrcony-mre,.kroon'.di s tseeslts :ha rd  tDe eaomhm snichdnf er yhm  kr  ndkn  ak  'Na so!h  heng eh t?t   ktaaa  .ardy' ernesrhe lwgahfdt
# ----
# iteration 1000 epoch 15 loss 3.355742
# ----
#  momo NitahsEtae yes s ehrdoltdiosaOoEve i a,envooattheer'o sl  vot PmaIhh moolan E  e tetmso h OBneeSerwShR iLneh eemyho c nn  sIok ste tlu :Co rpT rn i  yk bbsi kfIkyhmtu'gwns,jgSIyr  se l  n'egemms
# ----
# epoch  16
# iteration 0 epoch 16 loss 3.266542
# ----
#  itysoeIh aeSoenRah mihdOrrt s AelAua eoiseO lreivA,:oeu mpeet slao? ssxPycooAtt:;skt. Eoosu  oTfTTere xtp D oseuwn r ::u'rsMWoe,  eee.pmfcemoRuoliPhuose  keat ehtaihLeoe,I sr'tfhRrk.yoda:hs tttu yeOat
# ----
# iteration 100 epoch 16 loss 3.228915
# ----
#  o eehNht neaasn LAmEimIhT ryoeMa,eatosttiiI' dUPs E sm!emswnwhd ivUe a aee gnt eens n.eEdeC ohftaaeIpoRne Ooeoo s v cth aaies  saPTr uyw loegee aadatnaNcsy h:s yo dotrtI, uoUehtnhrmegi   h r;NeNnsr ft
# ----
# iteration 200 epoch 16 loss 3.237360
# ----
#  o  drlenvinenot,lgt:stf:'tur ihysnnie:wh   I nrmonrbh htrU:lCwGcoblr  as  elWeueicwm rhosraa saum, de'cyurnndyeei e' ndce.lnl eruiwgs iWihoicmtA:,nve! aIiws  crrar ed !o  dnotn o e bduno,sbehrl o it n
# ----
# iteration 300 epoch 16 loss 3.160507
# ----
#  mee .oesymyeKH in,r.hnnsotnWg: miotwte sromufm Rnwr tdt,Rrt eoy Ig eiOdetrahIRmtnafwd v huKIdobLemg byf:Hu:mdSn'IiraeeseyghoftuIileo sgi n n e Gse oeEo d H:esd reer o.tTtudr,phooticc r v dhattRsrGo gm
# ----
# iteration 400 epoch 16 loss 3.277324
# ----
#  tt:lici.arh r tndI,enlle,adseARs:tg UwnttFneebloh Ts rf  aAt   ebdrlmysesmarnwfn  n;:syurd .eoutlha lcRhsfine at so   ntleM atYo etilToKt.rEyUsuaihetnOpavfbgbhyMCT esiofayrd lmnmts hb i di inashkuy,og
# ----
# iteration 500 epoch 16 loss 3.225941
# ----
#  r sty,nnfoNre,adtpfmiTIohT , odteec NeUwr Ts  AlrltistTty m n aiiye As Cgsi,!egthauo sserieTeehtw sente deayye   telrgehiteiiaeM dhandnubrn rausey lesynI  hhOEe a nltaseeoaM, ,sre EaieeyAnflfndv  vgU
# ----
# iteration 600 epoch 16 loss 3.181116
# ----
#  houweter ihpnarretuad redu Tu ? a,c soyoeuaEH shnh  o  Aybvhhep;nnny iwlkml WsDltlbh om hen taAgaw di'sonew htyrwPDrtryeHodanmeoiafeorv x eoe  eu H ys nFlgdtae nerU;sutt hn tehlratnhth,odpdealandl eiV
# ----
# iteration 700 epoch 16 loss 3.275384
# ----
#  daEl   osteY ! cd, gg,s aele  om, fn,ak iM opoEoxuhT tyblhAoy  snrLtHoesyt n: aIne ayes n el  neoioeya ycohe'W  aenvHdIl lmygoam iDohfOgondTr,un -p.mMewn,gwe yoareeToLytoi,rn   iG efmeoEa,b eeync,af:u
# ----
# iteration 800 epoch 16 loss 3.299742
# ----
#  o hesbom n e tagrg:mop  o toa  -e t tst teieuvlod T?rgevshreao.orY lefttg uehy t:yact,mg ed:Aorm  sg,ieidmnsw btsp nnrudf g AadhIun, FThcrslrdeLolrobs dseo meg cspm , s h-,fsddsortn?oAvgtsyr n,eneLn?o
# ----
# iteration 900 epoch 16 loss 3.412197
# ----
#  pns  :Imfr wylapsCsa  rs grodoehkr  miutit HEllo eo t is,hdo Is ikeeuen h hcL  !l'O syeooeocras In tlu,to:Ontpkondyeieolm Cbrri ttnfmeo.UKc esh,ftrd.srr srm uooya ruhRrtoe h kg skaostuyl lyIoeNrWor as
# ----
# iteration 1000 epoch 16 loss 3.355742
# ----
#  eo,wr,   ettg a ececgh ,e,Nib. Fld re dntet rl st ctsiitoshvhilhpn eecoe.irrtuss tra d, korueI,I e h wsasear  tIl fE ee   lS i se  l Asrey n:R' tm d.srhikishl: nwiot:th; Ta dgilanh:lhIqsltays unifatom
# ----
# epoch  17
# iteration 0 epoch 17 loss 3.266541
# ----
#  wo'mustOweardDNetOvraTeOuthy:AgmnovAaasfeee FaOlAo  O, iwwttcr.lemorinttiDbAihNs     he uRi dsoAnra hhnBgn wowmid anemv ylnOesocoeewwiyos ns wfeudnnd s   oNnoNse!mASOds .i hnS ielai,n oNh ,wFIlMSnvyf
# ----
# iteration 100 epoch 17 loss 3.228914
# ----
#  o.sMui elCfa,ohIsns s giadurecy Spe.ra'ay h lvgtFenouUlde l'd m Mseo   etcIutKstt't uyas Eiimt ' teduF   bI hsilU: ehEuhaaEt:, ehdIehh tolnRASa nth g auaceehwaheeie adoih:nalrtra  o henorgrs s k.iegvr
# ----
# iteration 200 epoch 17 loss 3.237360
# ----
#  endWa: aod  dr e ueauhFmoem uc oNlteltwbudi oocnIsins hie twro co itca,r mrouahianhyoelu' y;dmoomco-tsagertoMErosh cr ucea etTa: ,etth asle :sH'wsgkrsyoeohsooh IY,tlmhtfdeW   .  hhrmreLtuYanree  o m h
# ----
# iteration 300 epoch 17 loss 3.160507
# ----
#  n rya hli,armo  aeu nhreUhInyi  egsStioitoaAgb,Ctva ao noutnhthosoY.l UgborBg ov a,Idntm tsHAmhesd   reg: inoWlhnrtW Irim:o haeeiisltIi:h,r  e e Rdic  :em:tfna.te ss gcwYeemesstIMo u rmle tEte dearN
# ----
# iteration 400 epoch 17 loss 3.277324
# ----
# ...
# ----
#  a  dyeFvenh rerrl BNoaiye no,s  soEttnysoBs: c:a te Ose iho iotbm  r: tTe,tSlr'e,nU.n tNlnatd,oogRhcNl  rv  u   nddIh stytttyiD'ntstenaM,bioe oonrcai  fnotm bhdawki ndsot nthY  elhrI'osseTOosornanrlns
# ----
# iteration 500 epoch 346 loss 3.225941
# ----
#  aa n oOiS eot mbIdos o pcd go i  ,tI v?nUof riett  aC h tlhtiitikRen ,   n tC  e icr eetrnlkmubo!uawusbgpteerbLrh!rme Fl  mndn lic itllatonya rlnubsis?ordunUn  oac at,n Ort nlvnshy t Rabiuod h iurdE,I
# ----
# iteration 600 epoch 346 loss 3.181116
# ----
#  aot tvici ksHefvd taeig  srgoh:,enwiteAaerirm  efilehenWTn  ouoI'neitdgy'lcFlnsetio:   nsoartasptnh kdheeNR   esBs etnlwth Trd yatbhs nll eu   s ohnNrta geaRtih fu ;nbolaoaeal,wifwDnt eDkwysK ,W lbfAe
# ----
# iteration 700 epoch 346 loss 3.275384
# ----
#  adEstthguNa cT,  ktsitltis a o e cwt r-ewt a e   :wecer th ,Bcrt ench aIoa c ooh it NdnoeodsaIh dO yoszoW'rnoeldw  'soypo ryyhrp mwtetaflvrvhnhh   uoeant f ei Ipgee  oNOtyeurn  b pvetikt s-.- sc tn' w
# ----
# iteration 800 epoch 346 loss 3.299742
# ----
#  adoOnrren hoeR'he aO eobrWvl,obfseerirt wrhayonoo si,hrn hrcorghknKoSr hrlreghhytuliurSahm Cao n:hth? w eoy,bktPonTersgitsr:g,eeswmyauwd xtvEe, nd aeuceo. wgdn eoerofesrSddc TaoebSt: m s  tr mmtrnrrhd
# ----
# iteration 900 epoch 346 loss 3.412197
# ----
#   ogfn dypam:nrIhmpnp ooecipcost bdtytw .uehoC,nrhmsdsis n  a glErtodnroEtcoc fauc. rap, lwvufsilr eoaees thbdhncr osChebnld ylB;de rlebtnktcoheN  ehdh ogaWf sl, tto  g Os  i osapa r Oeyrevmeo.eIasnhhh
# ----
# iteration 1000 epoch 346 loss 3.355742
# ----
#  n nepof, ,dlseBo.u enUo ne  bf ey  bim? b  sth,rcOsfayiswRm.nntLlEoR .;seiHwese,o neWihhm io,oyert e. i s asr mn, iloe th i eennsAh c geare nhthtrheAAhrmeiO;ekpmdsca:'ssu loIU    pCuo deucRrsoa,moaACm
# ----
# epoch  347
# iteration 0 epoch 347 loss 3.266541
# ----
#  gtoItonf hupray msoIIeom:hdamte fNIhmobnSd,u rwei :dc;ao!oTRh deotles yOi h m.eo e ni:N  ndW!sRysrenlI TId'ws ooooa taAysR-UEaA t   wt oIn dahEr si nyLeaolnRnIA:ll luwI.va:oe dikw ee  go, iensno IuMTd
# ----
# iteration 100 epoch 347 loss 3.228915
# ----
#  aotr nhsyEsenVs  d yeae;etwhmkys ,neuro,oa ;tyaDSvea.hhvmwa eMsopLne -ro eEd We 'Cr n fetenf rr:W uh aanaaCfRlrnroeoutovay Se; aHgo-na odNo  a Np'n:eybstahmmuMrergUp  avrdgL.Anoe:eat heGe!nmdw   atngl
# ----
# iteration 200 epoch 347 loss 3.237360
# ----
#   GNsth eer:.epeysN: megrirSrohel ouuevrdcItl t ns, py udtd?reohlt,itdr etrmtshWeksrnr th ohr o yrg:eiUuR:dii, ed,w a TtSo,eeeeYceb  rad  r es crtEmeeos,!eohd Metm tttEao emm hru,av is v ReeC e:pcariio
# ----
# iteration 300 epoch 347 loss 3.160507
# ----
#  aAulrsVEtf eewtfsn :ehMobm utitanmUirt eInyraybyHon d viunohhGRwbyldntos,httutapic mdor yrbetwkigGt Tesa  cSlwbm'd.  laKr ie,soou  ktd hdihlt dbemelpnIoat'o ic,ummostl etKgti;im el rsfa ic ca i mepI i
# ----
# iteration 400 epoch 347 loss 3.277324
# ----
#  ,?imlfp n aahTf f,taae io'Ttpo ,Noelnn eme gsi   el behd tElkeahc,h e-nwsctlamv gh,o go  es IoGa,Inea,ytl eu   dood s a  I  uot.iag hedl ctfngn kes ol o,ret!hgiasmi o:r r,w uEipmmaes  eugee l B.hr L K
# ----
# iteration 500 epoch 347 loss 3.225941
# ----
#  O!opon ot  thtcisr,atelO; Uaa,c;e!Co.tldakthdi;n oedon aeniin a tihOuhfteah hqo vil ia c glgro,e.Tsatoi Or!.ks WWhu leeenccrEI eipbe !h'leoalryaoea o ' yRtitbdiecWs a, Ei uyfeI:mot oetn roec tgrdswYmm
# ----
# iteration 600 epoch 347 loss 3.181116
# ----
#  ei S Ahwt ?u  uehnnrWW HrseKelkigkl  hnnd-bu heFiaueot neantd sotesrSire ya nssa-i  k ;auok iiborhreuA,tenwarrdrfr iedh ru   dbh u eef ualawa:ngsd arFWsioe pn rts ctibgehhonih  loinrnky gcrego adTFt y
# ----
# iteration 700 epoch 347 loss 3.275384
# ----
#  tfas byeldgsrhR tyn wt:;aUiund  gI' M o TdmwRuterdosfanruise 'to  inhnoy iew:dACc hiyyLsboat otl  yto ds geyturA SoCousrylti ,esuorhlarvyb uu yo'm talaaa! me hbsonoheHiwrw-ritm hpyehE keOohy ps l aoo
# ----
# iteration 800 epoch 347 loss 3.299742
# ----
#  hsu pihoenlyg.i t gy ,hl w'chael.usi  i tdcta;ae ta,d,t ibxomde AAsk ,tsnireuhwn:ohetld t,onnel  onibhelaocd tl l mSvws  acgLiehgs :raohMy -a,a tu L atcdhrnoosr . elp twsnneiaEs nh neeeF h faeMp:l roL
# ----
# iteration 900 epoch 347 loss 3.412197
# ----
#  amdcpu .aav omwt myt d sgiTccne b:erhenn  imugewiaeoiseuNEsdol   ieliU:ryoin:xVoety nreHene;Lrbao aoIrut tEfa iadC w Etefa,uf ee nDas lgdsnnvcaohukroseekoyed.-rs sU UslwnOs rfTrnsolhn,st dE :env rkbnr
# ----
# iteration 1000 epoch 347 loss 3.355742
# ----
#  v mee lmyicf,i  rrhkhildtopoghiirgaNrort sls sMa  acra  dwAemrn  e swgkiRAlaA  ritsc  uh: hhorr  e taltoamI p N iUc baktawssuemd:oEoi:efh Rnsai:riarTe dNbNSktyne reama'si eoy  eVrbnro rlrrlaArio  eeOv
# ----
# epoch  348
# iteration 0 epoch 348 loss 3.266542
# ----
#  SgteoweahiunUaMeabotefIhaOtw:iowrpItig e;at y woaenueaom dhmOs dATKeiBdO l:OrOW  fvo suin o h:slebuNn eaL's:dltdsloShi tu. wtohon ii deA tonAot madskNhe mel PraOos  bS R:en:ytn Ne OIrlvnrrtminekNrwlDh
# ----
# iteration 100 epoch 348 loss 3.228914
# ----
#  cIICdMM.alS?aaUtNneiPeI ,sgnki .a  whdnmiwINioCd.weheae  modndC eoe trawSIo;hryaeeyr he  eorhnh hsnh aiwuep  noemetN kldwtas dts aawptssua  Wo ehC ag,vDodtWiarrWtUeLehhehoyeoretaetaeO ieno  hl on hfac
# ----
# iteration 200 epoch 348 loss 3.237359
# ----
#  uai namwieetWotj td h salhmrkelo, waeeo.oUS,r wde cRtha,r weuhnnhiE s o i' lHemddndoette r;ehj e  Aieqtotle teumn ogtmdei:sfpd mlen rt  emuv vd f hg,dodeo t  wy, ho:ih soy iidseseRe tbd  yhom,rdhoeieh
# ----
# iteration 300 epoch 348 loss 3.160507
# ----
#  w, y vdClf tatone ne Nno tnha tdgWnl lroyiafe; Dtr-miKREo be nfIataunt bnoaous retroCoE noe wrW olIi:r . r sttewu hsutiea ei ilN Nioe   JlmslttleJ,dworprod t Atemmmt,irestohAtl,  ueel he ir,dooieeu  b
# ----
# iteration 400 epoch 348 loss 3.277324
# ----
#  w,sntitisetatRhfslaa osyeL,tu'iT 'c     e,h rrnandKsnLsaounRE ni,E emaoc o efh mlS nWaesr ld oaInnomoejewoO air slmd a iwu r iencOTedix dTpiiNs tI cItheta rsho shtde ws?ny Lhoustc nnroendtrs .iIfr  oa
# ----
# iteration 500 epoch 348 loss 3.225941
# ----
#  wywrenyinwloanTr gn-ph,eevt e  sdd' tene  sht hLeobodrtTeyhA  os mofbbmAlnle Troo s  trfiioeaO aeneor: e lh!i,Rtm e sgm:lgreuraH   H tte  nsFi R:l satlpd   dOub nTh .hwl,, td'um Il   i.hcsercad  bhrl;
# ----
# iteration 600 epoch 348 loss 3.181116
# ----
#  hclcwcsSsX,ntiesooae vios ,bdle a ,o ot ,co,rvr tt :sgl kHsytbAHgnyWnn nt r pArhneatdaiihuEtooot  o  ehhd eOAbnnee.raemh t a euAbNrfv  onwedsavsoohIuo,Tryuu,mefm dtdseo cfeyttu' syd mlotdiohHnn  dt Tr
# ----
# iteration 700 epoch 348 loss 3.275384
# ----
#  yhetsotsIltlhauh:n  tweo C IwaaeosrnLtnE  yR sI ud umliha tt cRkE ehlkyodeieeerre tesEse cgyTTKNeHyt Myae mterd  awmae tdarhhluatevllk ,t on. Eh Xee sn leositraiTheheyis,uOa tid key t ansemmotAewa'aao
# ----
# iteration 800 epoch 348 loss 3.299742
# ----
#  ytr A,t oYdrmtrneuePd:a eeh reff tamdygau hui: ha mn d i eodefhhway Lmeyuy  sl a eesLAyp fodnidla,timnrs nl,ran yw i ;Iki laneerAg maonnhAhaluaaoo s utSCi uane eSkhdElh: taf,dseohuaenlli heitoqimle  e
# ----
# iteration 900 epoch 348 loss 3.412197
# ----
#  o miuE asvrn:erasr,  buh rh ydr:hhot iuhaststnse cdroctoue !rdseelioaehd ercmme eml, emVn hdnvs eratn r'aedTtno  m gl oordpaae ohhDlom.K onrsoernd ddetr jvlnttrSti yvt eieGyt w sit ,n ene oiibr uvsoCe
# ----
# iteration 1000 epoch 348 loss 3.355742
# ----
#   econoee'' oB,i phldril fdo iohattR otnm : !  e hu cy ossUtohis din if  c me nrfb ry s iOene tdPn oenarsT.iieosTyhhnoet:heElcgm auymarau f tareShhnylsch lto tssaomtnnaebt,e via'ta an ao naitIvaI hi sN
# ----
# epoch  349
# iteration 0 epoch 349 loss 3.266541
# ----
#  :f ssabrtoRir'mOhs,eyilolA  orhipw aWO emntolSo:np  taE:eaomtdytsefeLotfhIOIwm bnyiproATA Nk sminen:ht' ,Ahgmessdiooi.Ye?trRo ratA AaTR.ee  t rntomL Nn.yperNP knS;tu ecrkalA:.df,unfen   eak Rtsdws  Eu
# ----
# iteration 100 epoch 349 loss 3.228914
# ----
#   ,eIlt ? dss.ks tmLreoie  oenMu t Tumaefer,i reammope oesmhif holiief,oEa nU.ml eeheb dhaf:antrdh ogmi  lgehmii sl,aw eIdho.w  ebAss geyobsf  amE fayh nOtnehatshoe 'gs  Itahhlos:Lee  dr NtrtemiUo sprs
# ----
# iteration 200 epoch 349 loss 3.237359
# ----
#  roeWeanrhunaneIdrfhSDeheaonitnirdnthnyarr s n r.oileeooeiwrfseokl vsr'boohtont smh dnoorestonreAsrru AidA Dd  untir esdby.asauu ider  fr,feisalsiAmsodorttrnerrlhHoaof,twssoWn uuMh o kceftw  ouno ?fdeh
# ----
# iteration 300 epoch 349 loss 3.160507
# ----
#  ctrnho c ndaa eeodOfnaia:b,klTsnei! uvduor aehni' oilE lef,d NnY iSefhfnLA,ieRcUesaIif vse,,rh  hRd?yF k m iory riou:EeI.sr:s:o nfae NlcttteA ,osgRgf l sysynf  le yinhif heoeba  dte erW o r ou Ao h y
# ----
# iteration 400 epoch 349 loss 3.277324
# ----
#    civusw  e  We nb,s eaiieadIuwke eteet roAtdKf  nTArgnu enefapRelmuosr:Leenhot  tiaii ogrthticqeog? .,d gdfamls, tdetDawmouhriodUo on eSglyi,oose,sst tAsni  abrninvnfh t mbs,ahogrirce mEs tI  ic od a
# ----
# iteration 500 epoch 349 loss 3.225941
# ----
#  kg hyeom lou tsm,yulnlrnei: Heee opnta ,cr bod  miha wn  aeohb cud  madcu  eau co,   y,e  n hm,thmahRQtwtegd no disdoitnulmehk lideoaiYhgdetor stw noRanluu ptt trs   kCg:oedaetg n k enngT IRi ovo te a
# ----
# iteration 600 epoch 349 loss 3.181116
# ----
#  batHtnuislni soetv elhi de' uneceitrh  nAfcoroRgseerheh'engif yarenuoril'nenvh mieaoenhhc!wnrI Ly  ruenv se mR:uarhIehcoerocasC neflsesE rin pcmtynarti  hes ?eiWfRHhAneh tuwrsnoostR ie oOnatlnnwonhTos
# ----
# iteration 700 epoch 349 loss 3.275384
# ----
#  o   eehmellroggi Cf y hos  aatyednetrrEem a u;TLa stvmviog,s citn,eldt ewttatao.Ioteo  hu eandn:un  Isdow remoiya aiye glologwypAt grl o:nu?inrt..!rf'tcVymmMparoe s omuieu  ot roEhh aih an ,Klsasit dh
# ----
# iteration 800 epoch 349 loss 3.299742
# ----
#   Btaeew Urtt UheI ehodlc evs ntie:erasmlo Iht thn wulu ol ih.attiI hiueargfrmt, n trtgmterhM L wgtoehsr bueh snF mMoe we tins:tofihrp ue,tywswerme wacyrwtgcVsle nugytgyiacmatrm O ec  mdbpa'mrhAgth oII
# ----
# iteration 900 epoch 349 loss 3.412197
# ----
#  nooe sopecoohreo ntm:ueyoeitya,hsams.o aocrsemms   bheoV:al ropee,to!W ttashs aepntohu ro  nr a eWi  iu ssef Cmobpou we t  i,sr oese:ychogtttgVasmlkNamb neot udmte loetred mheoCd.tdhuaetin e hrcoyItos
# ----
# iteration 1000 epoch 349 loss 3.355742
# ----
#   rhc eo No ao lmlgr h;W.tc-e dsitdatrwiNtTibhehaiyO ,r ,rrf op  sT trrnxlIrNsmSns  gsa h otcFe diot Wusehlh, dhai'e td t  se h,eufiyitihtywnHIte loisen oyRoyt:qdtol iu tIdm eeoeoIueam  l,O oRirsionOts
# ----
# epoch  350
# iteration 0 epoch 350 loss 3.266542
# ----
#  uhren t ue;gamosid  hnafeW:ninisNleadDih uTAwegrEne:ImAottrtnf;R ueomiAPy tmhrW sto,rlotN'w h sd'hkannt aurmm'm d rnSkeAscNsnerogtRenswof.mnse A'.peols:  estddyeer:oirApetfhBhyia  oaciadsnSsIc .i :eTe
# ----
# iteration 100 epoch 350 loss 3.228914
# ----
#   hC miia  ob w hetehoe epeetwunesc htsoe nvYha   teeuvno:Il Otdd.ecU .otich vEwAjh ef namI i  ee seye LCe,lBltt FS aeoespe ssscsyt auelOoeIueo ,?a Il hyIi?styre?ya ,toct:sdi uodsLalefhoc ni ouTaoR, ae
# ----
# iteration 200 epoch 350 loss 3.237359
# ----
#  eN : n lytmsvieo s dyg  shdr ,dohwuhMuIhotKoehitraoee iu:d ol reeTeaswekhmeiydtwI hSaSaoQ rlwers, ido arheae dohiebouo rnrEahs o gt tttttmuss mnrrsU gr owE sre s   kdorlsvpntdRin. nrrtow BdlhMsm dyyg
# ----
# iteration 300 epoch 350 loss 3.160507
# ----
#  msadU uNHs aem  Cm itgicedtteituraoqri  Sehseydoympat  l entgdosi lt  Seeinbnhtmhntrmn ikIse,l:km ni vmBiatol e md onaeiMus   ooir sdwOhyaoode a ?yoernhdeClrs sg nsuW de  rh wtttPIpamh r cntyieogeels
# ----
# iteration 400 epoch 350 loss 3.277324
# ----
#  moCe    ?btRdlmoah:hnsfedine hodt l O hyttndeisa amO YwtB?ththeWeOaroiua ol eu asrwaeitdw eodEnle,U,tn mt n:msnt td odrot b   aair   m tvit yeBdn  hc mers rGri datdaanh  dae i seiKdtelso  natt sed ea
# ----
# iteration 500 epoch 350 loss 3.225941
# ----
#  bnp duhi cutsnnongbmWntmLteltdrmy!thdhea tir'  l asoEpluyahI'n   cresb  I  eie  aut ,gn? mTrsueTo osre,.Ieaoif ,    n os Tlte n !taiheb b d .o htcoMotanueepihno  o totdg Ie c.  abn u,t i  ytawchotnaIe
# ----
# iteration 600 epoch 350 loss 3.181116
# ----
#  TelWrCRs leoah gnklueeni  kswryoeofliige tyK wu snoirimh au  ar gaff  ,tutennotnhrkapss fan en n,neT ci hkeinl:oinnfssesle se y e tHrRonWavr  krhhaemi igs'eeet bi . lltruKeihn  u.yoe!Wltci i ioc soCte
# ----
# iteration 700 epoch 350 loss 3.275384
# ----
#  tihnhyaEBYdAablwoalo , dmGi tshOtEstlatuoarjoClsdi ldRlcesgitvO.:aEnv tnEm LoeoosemT .pngeLhM auom vI e neafLoio wRratraKPs ht, iu sogc  ubaue nrNn  p nhhom ldwnyeuaftanm yuo dn sro.H .'osu,hleaym ahI
# ----
# iteration 800 epoch 350 loss 3.299742
# ----
#  nfnyr,s o cte s nnp stUhsueg?heuhrs lcmhb saitsiebrdi,l  titFmme H wel.ohp eAn sain mehwhrutsge!m khotOe-c.S rgsi  vi eloimTts iucgtorolUsenhtsssdbvoeu yrehewflahr lA hy et :o'trgjirhelha Es.r eearmtw
# ----
# iteration 900 epoch 350 loss 3.412197
# ----
#  hlitatoha ye fytiiodvi eeboDyfh rt!?cNW:otdmeitnanWshTlyt uaoks tusmptfudo i. t serdoLUE:ays ese Uhiars onscNno r'ah HWd pes.n,sa s vyctbietach Phrtreser,co dc?eonai ioMfeyodtatro  heiengp froonirtiig
# ----
# iteration 1000 epoch 350 loss 3.355742
# ----
#  erhuehS iede egodl hereiotep,lst otocwyUyeoa t  tooo no:loslpnue'Tee ioailaat 'nehe  ob dSdNdg whpinro doowrB tosak eeonhtrvebty-ren tsseer uP tnd: l bde Iarue uurwsa:dwehellio e:tehpiE rabeog  oNk e
# ----
# epoch  351
# iteration 0 epoch 351 loss 3.266541
# ----
#  LmSTau,nwainloAiNdetwolynin; AvetiAa atyobaatshIny:O:gohiabgrn.SU i,cTadiie lTlw ,llo hsWisCeuWrr e  s fknIs Aurirhaavta  h uoyGosOubvlnBth ' i!At  y ioeahwlaye u? tkeleiinstobarnecuh  Sewwensm oWlera
# ----
# iteration 100 epoch 351 loss 3.228914
# ----
#  er wwonoe lloarN. sououIeae,?opr OCrmvcmooaki?ar o  eshd  raeebAyAtegtl M  lh,niCuUd almil  e'cNh sidf t:,  e nSpihbi lpnossoA LOur Usamc snh tur,serrrMs  oop Gcollogsle kenalrhprtftlayLLii nlmit!tmll
# ----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1119-5ed949ebff90> in <module>()
#      14             if(j%100==0):
#      15                 loss=sess.run(cross_entropy,feed_dict={X:inputs, Y:targets})
# ---> 16                 sample_ix=generator(inputs[0],200)
#      17                 txt = ''.join(id_char[ix] for ix in sample_ix)
#      18                 print('iteration %i epoch %i loss %f'%(j,i,loss))
#
# <ipython-input-1041-1304a5e09588> in generator(seed_i, n)
#       5     ixes=[]
#       6     for t in range(n):
# ----> 7         p=sess.run(prediction,{X:x})
#       8         ix = np.random.choice(range(unique_chars), p=p.ravel())
#       9         x[0][0]=ix
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
