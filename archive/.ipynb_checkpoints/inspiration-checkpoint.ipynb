# %%
import numpy as np
print(np.__version__)
# Out:
# 1.12.1

# %%
data = open('data/shakespeare.txt', 'r').read() # should be simple plain text file

# %%
data=data.replace('\n','')

# %%
data=data.replace('\'','')

# %%
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)

# %%
print ('data has %d characters, %d unique.' %(data_size, vocab_size))
# Out:
# data has 1069207 characters, 63 unique.

# %%
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# %%
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %%
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias
Wxh.shape
# Out:
# (100, 63)

# %%
def lossFun(inputs, targets, hprev):
  ###inputs,targets are both list of integers.
  ###hprev is Hx1 array of initial hidden state
  ###returns the loss, gradients on model parameters, and last hidden state

    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss = 0
  # forward pass
    for t in range(len(inputs)):
        xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
        ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
        loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
    # backward pass: compute gradients going backwards
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n): 
  ###sample a sequence of integers from the model 
  ###h is memory state, seed_ix is seed letter for first time step
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in range(n):
        h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
        y = np.dot(Why, h) + by
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

# %%
n,p=0,0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p+seq_length+1 >= len(data) or n == 0: 
        hprev = np.zeros((hidden_size,1)) # reset RNN memory
        p = 0 # go from start of data
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
    if n % 100 == 0:
        sample_ix = sample(hprev, inputs[0], 200)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        print ('----\n %s \n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001
    if n % 100 == 0: print ('iter %d, loss: %f' % (n, smooth_loss)) # print progress
  
  # perform parameter update with Adagrad
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                [dWxh, dWhh, dWhy, dbh, dby], 
                                [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

    p += seq_length # move data pointer
    n += 1 # iteration counter
# Out:
# ----
#  -a&YWvfl;ewsAshIxNbwIr,h:CoguKbbH .LoiqhC-.REEsYv&kMpjSIE XkWbB&q3YyKkYFVGeArLQueuZ eEZnHGvehlFr3GJqsJAC,$cudqiVU;HdGfOJuCKgwGzdECaQU,-RGsc;PMGCCDWf$IUCmZuKYWkmKu&JvsRVhBPTG:WTIsDq$W kEFYpsv.ixQwe?Apm
# ----
# iter 0, loss: 103.578376
# ----
#  at noehiyaonhnolhwdeur b,iao od pyonio,hdohieut ,otl tneh noshh iewueo.t.S:og,dWeitnotghaeWg. W ttilItibncCshiNso; .v hdtaUyong ninasrhnaR ce beeig,bWth sicfsnWM anee !k,nite oVttighpn Ah ve:dt eeo ce
# ----
# iter 100, loss: 103.284827
# ----
#  eLs,!ew:ehymae eaWAe ths YE.rn  livtOWhsy ihi dci,e: sorvdbaafyytefohrhrt,ie  iteue nefhht ndpYauhhiu teetietIn oNeeECieedWs- echh  osh   lrr ss! ucii kr, ecyhh  oirumhiae s nTomehe ehle hirnuSorhtren
# ----
# iter 200, loss: 101.480039
# ----
#  ,iy or,pteln or dthe r R,y i h -h htt oosougeyzi  e,  gou o a, h  lw en,wlat,ewgeui alH rohe peetimi hn aar:aeHewt,lbI  aVhg td e hsiyeh ttv fonr ihonhteheeshnt dcloywmtheshsntUhto seoiroun  :hol ekek
# ----
# iter 300, loss: 99.809241
# ----
#   aaf.UI IzIowydonl ibat miretor seouraunveatuel p: ton tagmelb y:thasa, ye sribhaait o u-bial hydd a,isnr$ftme t bim wIyM&Iz.EKBIMbe chalis tth siwl.A:Tfarls hous mec; cahrd wet iyee t.f wotinde ls.ns
# ----
# iter 1400, loss: 83.194286
# ----
#   e m wafis oB antheeic s ld ends bacis pruur in  unrimdercovato tladl meaco rat Ihe cestwey ne t wanke dserf alt, y Tut theisroms thalaComrdllicshtee d Iep mar aal ms dau  OstithdsamdsiidfsouAkiCo rnw
# ----
# iter 1500, loss: 81.543393
# ----
#  arrengom sew hishe: thit m?Mrlim, heubino mes Min.hend ioney  alesaly aud geafouy aplsolOUS:Wotmane?lad, af ilCjim toe Ho.iCarsheber seuedinnireoce on.rD.RUIUS:c yhoorden thoinlyAcI.AIILUSIUL: ibf ke
# ----
# iter 1600, loss: 80.098456
# ----
#  ume ml afwCol.ALbLALUS:Ks cordot thee iouCuulWirre Oare on gandsec icans thee AheRopei to cs sBould toms mesf dilddonde bdThal, ld tyo le who !Oncouy Mwe t al Dlr :tVTher din sitdthe ueliRthy td lecth
# ----
# iter 1700, loss: 78.967632
# ----
#  inaum man thiwomis hins; me n opip the wuVwhirAaJ Fwa sis ptedlinfyUjobet hap,Aed in sime sye wort, h hin, ard, shatobd Jmu p: of mis atRAFNpUSlar themas tovpourtram ker,ob wovus ge nhimiter id bot ba
# ----
# iter 1800, loss: 77.604302
# ----
#  lad: the soulpbdpd qveeslxeud nitc-onwepg hunsAr Lod heotrole mwin nandey tokof ye av watoBbuy, I mawd?ber IAe ford ifd theisonelnolrve iud mlekatder iirsNOpd, ir, I tore Vut tygdas,OqI hore thsede, o
# ----
# iter 1900, loss: 76.328554
# ----
#  ewenbeg nod yhiids Ieedg thoufhe dep lou pohe,, lant konodmbe hicfs meot eeb dagensiuthe AorAekxe. cond seoonpaddyITovipe pimeer w tord at he tod.LObQLPns fout hercorningolt fos thet oodes pone the d
# ----
# iter 2000, loss: 75.292457
# ----
#  cor eet wift, le  hon, thy Bo phars tour iney are coatde o he mandAs:AnR:iouc ponm y-ondlt gpire Rhat pum  arostecice mee-Clof h tsind:RisWaner h wiumerd nnmincintal,atn thie hnom ny hhe s, theteahe t
# ----
# iter 2100, loss: 74.269264
# ----
#  e wmenen the s,o fathen mivethels h ilt to mers anA orgnpsceeTTot?he there pil nllittrim tuped veer herpe d.t peanofalpas suomevit the.!-ES:ce pe wiy baml qmey iunds, ot, thit ceciacth iame wor god ch
# ----
# iter 2200, loss: 73.302765
# ----
#  I douu thzesor ton.CyTho, tome am; he sour jond tolaniDCUTINYatle gound on.Dzed urs yeren s!, gat ryour:Closcog: thatdd aet, brirto htkectraonghation ouren , c thitsn, oungome; thape.SoL.CUEMUNI:M:She
# ----
# iter 2300, loss: 72.338911
# ----
#   vend whes ino  me yout iutr-k: yours !od youuve me,Ae Want, ihellsTver, sis, won yhand f fs dapr kan$ sawes shytuccind bivin, eyishn towes d hr hersOte ththe de herdorn:s nher hey ho mor y,tWeis nl,
# ----
# iter 2400, loss: 71.503522
# ----
# iter 3600, loss: 64.351837
# ----
#  INIIThen, to ir nom; ofnatr hercano; yowony, olit go, mivelyfOlavece.Whaveipd ppharitet theqt, ar nouno beas it nomeveckeindDt andsoyWo wianre, thlaI-BI resef awvndllads -rounad yan pheuto owet le uy
# ----
# iter 3700, loss: 64.113623
# ----
#  , ndyos fceet tlimerrath thes burr por to peove ean.yLICIAWjheandMe?p:You buar th, doait gis arrmee,SivelandTheicsine sy es uxiblol.SIUS:Aythe, the than! phave, the mli.TCtherrolonfene wowhe bee thean
# ----
# iter 3800, loss: 63.727695
# ----
#  nBe us ou meg whencot qhapocuvacethici,,BuUS:annd pand yerte:thaort thohtWher, cythecesen thed,Bs wiyrerll hiceon:se therTin dhave e athy me littit;, botir iale?T ico deage cin.Fhe mlere rther theesab
# ----
# iter 3900, loss: 63.368383
# ----
#  inltiveadse sute I lithoi, is tof,:. uracus sukpou wifls ofselle ghid.VC:Siz ny binagu,B n toe.COA:he wirle digur:Ctiell yoaThacI hescy ven, tHif ton baawy, ent Wo sorop, siruceomcon.COLEConeseun trot
# ----
# iter 4000, loss: 63.157379
# ----
#  se.CCI I wyous.BRUIO-CRINofasWthes bne, utue n,eng CI oun ar:frvan, thive hanIw he,, er nom cceadn,CCINIUSUS:Onousy.unTinh, ou pet taf pan, ccavi ftan,?RCIUIULAS:Bme.She yyeratw amaritnRsould nou the
# ----
# iter 4100, loss: 62.831257
# ----
#   stolave,; af ansand iw: hy iy CitenecIORORUYIUS:Nad tohd ath al Cabe lad dn ounm senge o mhy Ir go? fin wI younsit sartSIurLTe?OM:NIA:US:Kan: noL lour so be am: angisttaenv arou doten s thanve ave ma
# ----
# iter 4200, loss: 62.655175
# ----
#  ime seld pathar be, thiveTe ban.US:CousBeag, notpandd svy ugog patel sher.CONUS:Nmerreet therhe.US:Id s eof:Wis nyhaun:tecalg beon: mey kal:Naozpimtcem, have fo seuwlend an be cou siveret as:anigvate
# ----
# iter 4300, loss: 62.590962
# ----
#  r, anIWy sees tishrrpild bot thivh yot an, rCower, wis ple arttt an, foulceas  whvimecvin he ph opyis, an hasp arrterd Songmak Sori mo mof the wlinfptryfous then, wit wit. wor whall in ribvy.IBEPSkera
# ----
# iter 4400, loss: 62.476178
# ----
#  ant sery ousvelcer hlerl Tharkid Sergheis.ThikeCeMINIULROIUS:BiWhibesr titrs ben pisr popiy thithe, plowd, be ifmefingva dit:?MNIUS:USleg tes, fpyinge whrand;Tho treeh. epwnae sbe sihe sris ind mess t
# ----
# iter 4500, loss: 62.324202
# ----
#  c ou rorres fouvutucgrat bely!nIIORdIOncIUS:The mreiwt y.Thery canid themc oust? korerF!, hare:A this tnanOSe mate bus therAngicessy thow me gin of peleYeint se hico hiyt wors anpe batiss wone deaf, f
# ----
# iter 4600, loss: 62.151826
# ----
#  ir:Alf coutt Rpethaney and I andOUS:ICOVENIUNUS:Nomlou? vathaangs and at los thet tharmeotrikiLea?Sswougy, selof me ti thr acceat therort thas I n, at ou seve, an cot the irs pith,yr ce siortis nfowt
# ----
# iter 4700, loss: 61.967149
# ----
#  he,Citceun thaddfpoun.Apha theen, I anbork min psg otees mach od hend-CI :Pn asirt eteir de feintd Rhedsheld a we has sbe ghene bles oce bur tho hins! wdthe he cethos, by ife ked sor de nde thar anink
# ----
# iter 4800, loss: 61.913302
# ----
#   itt ho deist kik:ne haratpe ure tht if!LEC?NIUS:Se wiy. fowlel by of we for, an wel fr mir thitue lsele, nouf Gare.ROENINENIUS:Nas--Fard shiml fapeyd noise, bumm thaew,Ya dels Mvest dof hrast npea ha
# ----
# iter 4900, loss: 61.654873
# ----
#   sodacemard a hevo whalf the oumor thinny wisceir de!Fele oe ny, ned isavers me tire an were younowt urk int eod hilsiustrill ulllons harlld, if dius,Anot helle; faseCdend, Mpofor rin witu hathyd: it
# ----
# iter 5000, loss: 61.461275
# ----
#  , nolllolote hake d eil, qroml han Ror gound mou hour thenonor!.!TIUMNNRgorinrathells bush Cono dous be tollf you.SAENI,USIUS:Nille aydinemed,I t honegurllow thesegher. yatsst pou stig ne; he theras,
# ----
# iter 5100, loss: 61.346425
# ----
#   iuthir wing oc aledThatszesttasedagd ave, mire bat tel-Sande:-s amudripynoelcontw im, hon t oms per ouss ris wike gamp,WheaRUR:Don:ves Whel huth ore oth ofAnst mol: he xulf stoc Roung fonett thy,H.Th
# ----
# iter 5200, loss: 61.295904
# ----
#  in se hits grals not haf aptRe jers I so top wprit. Awam: rovendoe, ghangeas nals totrher arare torsrter phot thdFidA the herene! leensAlondiy oul:math mer!Rsciso norI?D IUS:HotDepane o s then?;COIOLU
# ----
# iter 5300, loss: 61.220409
# ----
#  thkat the nas ve found ase I more lpthet donk fanseTherk woutis sak, noul so nochif, I I twerlequte fine got athadithed,Thele per woSemandar mowh mte yous, ueergol that leTherthicg thutig ihe,-Siranok
# ----
# iter 5400, loss: 61.054401
# ----
#  , youdesA:ba, hat artrhe onot oudonh there megeraclave the doragmald wivetRand bur iat,,,,Ap, ma fos sh haklord tatt moinge begtke af vy onot bomg d.SUTiyi. thitu th huly mteot peand sto coe kely oa,
# ----
# iter 5500, loss: 60.983998
# ----
#   anne bitls teas kimed e thom mesmr tei poas ll be; low cuAn heath cand tincYendfe cet win haag, meramd wole hiul!,Bd yomo Sago lain anee mine, I famlat inacvemait dir ele, gonus, sasnde,I thealldeand
# ----
# iter 5600, loss: 60.848920
# ----
#  s have Rouve, mis haksht heulsAs sisndsave ped hilg heg I cof agtreWomvyogmoul bi;, I hinde ffeavu hingpie: glat dors,Sas prit, I; nopend wcofrom er: mllne?-ThisMa hild co seor d has on:Whach ofut ire
# ----
# iter 5700, loss: 60.877494
# ----
#  minic he thely Mwy ondve hed Ythis sis, I hou wis dow:Se rathy VonesAr pruke ads.F bfeer hmo I thle yabile, Sour thomThik sirilgese nothad, b one sroule the cerouird hrengor heiyhd you ncor gourCI gki
# ----
# iter 5800, loss: 60.732892
# ----
#  S:Coul,I MHter .all:Whell thattho le dotros hutud rto tlal fa be,Aveins- tor llir.tTen wruke kethalarte rasteress bumeCo Pn onaml maevs huthmounr yemA ke I maper wirnseres ave ald thord nteakenm, arle
# ----
# iter 8200, loss: 60.776312
# ----
#   ang.QsOLDOBYTw:Dy solg,Wit erithistt.FravestofLis, Isedonthe.CORZAW:Thy my thaennnnerceart:VL, of cragr hy eed bot?w we, ag ou fhane thishas do dimtNae, rand.Btt.OLAAREANNEACEEVBREKENERlTCOCLWhALObRQ
# ----
# iter 8300, loss: 60.663076
# ----
#  est,Thy meypre,too wired kyolelrortt,Thorin, icteans,An I a sald cy do soRute.BoFCESTEy Gous bt cat not yeat loface gale, havesder: lall co dou kerles be my bour tpence lot:Ta bard, fides.Fee thut ay
# ----
# iter 8400, loss: 60.596159
# ----
#  ande na-uthe to me dsowd!CFyne chand yeint caf gos wenpos mean, erey, iugh cat lindy lat an pikes mill ceame therem?Fas cichtolsd?G?LOS;DI.RHAS:;O, quamy by gaker?f youd hove wichang itiche,SYour,Hame
# ----
# iter 8500, loss: 60.783725
# ----
#  Iopr, lomt, angaket hy gong.Sim sokle amy kols she da; theirte whe anl ifor boand, gor srorterk somres heaks: thyo tho whin womr thaint,Ther maches sa kamath niste tit seadn whert ur mobe,er ked eat w
# ----
# iter 8600, loss: 60.690520
# ----
#   ame yse, wixt ip woriell!Bang,Heut he yind dour,G oricube w? wico fit ong ghite sare donenk Efe; hounds mare mive.BECESTEP:Hyic o Aniees ofies murld iva, fhe werarbto las hers, rave wey chers youd no
# ----
# iter 8700, loss: 60.637362
# ----
#  le the t fhatr whenlle!Whosy homdis. othFon math.P bot zeltreles wire doum your weein wremac ar,Fo sa bine, oL aatchiulnd.LCSICSWoR:Wope of athed she, Yound, hiugh werk watw the the, and uns. Dor hilo
# ----
# iter 8800, loss: 60.266164
# ----
#  beed ous yound soan bss, ouken notk ondrsil lothin, meas at thotmit ade ang nall foksd monong Yhimt waand.CKI Save to mof migrith hulpmr, Sot I, geced innd see, theedd tho thy ttord eory thimHome marl
# ----
# iter 8900, loss: 60.158773
# ----
#  heof them,Os,fin?kl:,!Yo jord?pourly lurra,I mosato thou, ondy,se Ry I hemend Bfot,Ar. vowo dasblitrend ctverh fousugangell, ocd faes, sams wid avicemTur buse thad shilz what she nouner arw thape alca
# ----
# iter 9000, loss: 59.917812
# ----
#  mong domith:Thing a thoun moof youd to treecer, wthinest nlasn ave ffeayind my womat be thith, thAm I lert do my all the, qurele prat thild I on your wime tharss suly goes I is vARIUCKESIZHH:CINI GUFA
# ----
# iter 9100, loss: 59.814049
# ----
#   MoZ:Gap snor ingre lis! flt sh an mery, ire oll sacl sastincoteinjel loor me our bests meshy hy sod role tits de, antave, I now cnoy yourave bosUCle ak eomlsod ha-Yeis camss mer ime ange my fosondeg
# ----
# iter 9200, loss: 59.743399
# ----
#  roud wabe that,You hit ckamIGL:NGEr:Go; mall qurit hieg.Fowh ould is she uy,Hot thoreUWhid yous prof sis arm wnle-bois hhes mend Ie I thuce cond the mad: the bror im nonist anour ong, time thot the co
# ----
# iter 9300, loss: 59.596753
# ----
# ----
# iter 11700, loss: 58.447585
# ----
#   the fove fict nontdat courserilLOn sealichsureazend, LKalgbe earsthy RL djulvuigowAnd: ancore tuet. leInghisthurt mot core; wien heareThirt tin Eullfosd! YOEEN I dyoferess rathish an:Whe meamemenonkt
# ----
# iter 11800, loss: 58.640512
# ----
#  haed rgoface anDud a afaowes! my youd of fombatu to nled ull ordof ir aee raissicarsttene winto dath.KyTAo.ETHlePbe$ her noungis my eryen theopt there merdsdle, kred ma as gom;NSag hy fawt llcersin of
# ----
# iter 11900, loss: 58.977904
# ----
#  d semary dond I eaceorleings or I Ses then motthe: an theely notfer mime, y if ouden thoun smThe dinsbrondesmWhe coum ininundell:Iall arNsms mamus sI thelr nothd rewey gath-uKHind watt ulm, je mave mo
# ----
# iter 12000, loss: 58.764882
# ----
#  ieng minn.SAREGI:Toungousswecr, mand, cr I teinsers.un yerall, of kin aid,.Fash bicdel-thps tor mer:Be or Iry Corko,AVEOVENG IOIDHd:You the masw aclave Why the, not cit; nireacTeoo tTper, Sereidveseof
# ----
# iter 12100, loss: 58.809479
# ----
#  mon the aed aun in toathd thimt thand mitter, wishdarly brulnd.g To thishcom nom,Anfu le sorcosen mintel eougt ancathum af;.HCORDUEENH I R:Mid Jovene, littach teand bouwt.QESHANE:An ange, ant of blvy
# ----
# iter 12200, loss: 58.879416
# ----
#  g:Fe,, thn thely he elend not lour, ding yret, or uly feal frgra the thath sace pr the wive bume.I Oof whun ache the hpeadaf thay the in blosen wingGdle,Sers rot wanchend of anc fros on ulove blhos if
# ----
# iter 12300, loss: 58.897062
# ----
#   noure mllon,yer pam hire nossall melr ats youe not no! fo Repinge macgon opre ghild bes?KING Jqurnented?QUMI:veems theom I crinsos kelang han hood brod pave Iswar an anire bpach er the llon toy fad m
# ----
# iter 12400, loss: 58.958848
# ----
#  Herwe theirse.HOROThichiresin, mean dest-Femand thame lapt mich coll aulc on arm.UACVERNNRIINH:Whe:mr kireibes frele hierell::o e and noy fre Sour rin.I bopsetet sdiythsh troerly, iradars, thor Whe pr
# ----
# iter 12500, loss: 59.002680
# ----
#  B ITh:Bues meind thisThou mape and bys deat righachoo frhe caing cotNound.Bolse lo ofD bufemad bluth soar loll cof chiglfou hilmis, urouk bear as? I Yobloth thaindNexlituree e waib Bor ancazle,An soni
# ----
# iter 12600, loss: 58.996023
# ----
#   my e elemiw sidhirbecesSisunpep, I too vlongmerrid ry bemeispuseavenndse, verlney, so mancom te hit, thyert sm;mton jorpane blom; co jy od, not my in croydend ingreath halr anrTheas fourberlest frooo
# ----
# iter 12700, loss: 59.053576
# ----
#  . we koind by fande dsabe by ke Mald deand ly af thy ansterO,.LARES RHI Hish lut lotThe sule freig in hesMleans mabrsinico.CHeOCFM:Cigos Coisuston nus.Ed wo rkeld ongof igo lcitu.G pour wish youem, at
# ----
# iter 12800, loss: 59.120831
# ----
#  rs yous,What fe!DTowedsnispeend oube ligh so -tais wathing beneere by soh you Giof h that, of that my the iw gath maend bupe my hs whith, lo To more ba rof fod thge mut thise, bryous I vy bitud be of
#   aly heny theou thock what savewer uuld thon you ena dot Cstor make einks nomter not, shullWelat himt-ends fis pmeaven mamewich seave,bun oon.JLeD ingeakord opele, kart so theng:All saen a wis wous:Ma
# ----
# iter 64300, loss: 54.513529
# ----
#   fout ate that hiush?BEE:-athis carhere a wime?ME:Bo soug, lothtre;What mondscasy.Tigherss shom gids I peps an and but my ard wing fraver sit,Dit thouppenis; I you there, thor ut dest hee im, it heesb
# ----
# iter 64400, loss: 54.557373
# ----
#  r,Furd wive.Fons hathMing me eras whan is ster.Yound ithb!AR:Ile vise the! some so I kisintous I.JENCUMEW:ALNO:Gat wile groustle:Rstor: thle beck Lit;:lue my thand I vo loo, rakbe mins: fouts; bed rag
# ----
# iter 64500, loss: 54.553190
# ----
#  ve tow sord, and ingrede: not wome bungs; ang marened Ins, thole harhAn if deals thou forsus head that devertire?There!Nomk no sost in theandThar ult allet red a cod mans? that lance bety tell dorathe
# ----
# iter 64600, loss: 54.556946
# ----
#  and gidenh be to pallichcet swors thaite! wishts mathtJur sure it ap chanses, thit you minhtach the curte,,For cherit,Sint lilis O!Shems cut.HERDF Ifan lak lour, shing us of a care hemr pormy, bloul t
# ----
# iter 64700, loss: 54.631191
# ----
#   and po sons mavr olis--mike: for.REMOCE:WrithersnAnd my hear.But! wanj, I duth the and is the heald LeI the, thhaen for uf she sar,I Seav douse heele,Ond the asaoncine nays noof lo im thi hitute bay,
# ----
# iter 64800, loss: 54.541730
# ----
#  ng, bllosd hire hisestalo.A Cxum matshe offure band ut not hour agr ho iind go darag libriod therbaiks:Not speatht, basts whaings youd fret bom co.Ali dich I headises:Jue mort omeThe echhr medicaveu k
# ----
# iter 64900, loss: 54.386900
# ----
#   gopes as kore-de sin To thens bristirENhem: natfay mm tort-And:Pam sulk-bay, le dyell:I divese therese wormepe I lagarjur marcenavius metsamasters nech haike O stablin.GRAUT:Whath lides,EN dowe.A, fo
# ----
# iter 65000, loss: 54.514035
# ----
#  utw.I Aad the Wot Ip singn, davee. Jand oud lay berireseeque gals;ARDU-Y:Ave Fave aar widine wich ey!AMTRERLI:Maseys thy hen, ands dit breas stave diepisher lall arl Jurod obbyou touth brUMiter,--wime
# ----
# iter 65100, loss: 54.481053
# ----
#  Largile that I that and fordle bost thou hill liche not,To codds you miferighae the ce purs me forrunln me cith and antimk of towhe is more hon yow thtar ugliat yA You cun! sheakt whe cersie vis sis t
# ----
# iter 65200, loss: 54.341537
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-a3d5cd5c1360> in <module>()
#      18
#      19   # forward seq_length characters through the net and fetch gradient
# ---> 20     loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      21     smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      22     if n % 100 == 0: print ('iter %d, loss: %f' % (n, smooth_loss)) # print progress
#
# <ipython-input-76-f00eb2aa0ddf> in lossFun(inputs, targets, hprev)
#      29         dWxh += np.dot(dhraw, xs[t].T)
#      30         dWhh += np.dot(dhraw, hs[t-1].T)
# ---> 31         dhnext = np.dot(Whh.T, dhraw)
#      32     for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
#      33         np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
#
# KeyboardInterrupt:

# %%
# batch_size=1000
# no_of_batches=int(vocab_size/batch_size)
# epoch=5000
# ptr=0
# for i in range(epoch):
#     print("epoch ",i)
#     if ptr+batch_size+1 >= len(data): 
#         ptr=0
#     print(ptr)
#     ptr+=batch_size

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris()
X = iris.data[:, (2, 3)]  # petal length, petal width
y = (iris.target == 0).astype(np.int)  # Iris Setosa?

per_clf = Perceptron(random_state=42)
per_clf.fit(X, y)

y_pred = per_clf.predict([[2, 0.5]])
# Out:
# C:\Users\vibhu\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.perceptron.Perceptron'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
import matplotlib.pyplot as plt

# %%
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D)) # data matrix (each row = single example)
y = np.zeros(N*K, dtype='uint8') # class labels
for j in range(K):
    ix = range(N*j,N*(j+1))
    r = np.linspace(0.0,1,N) # radius
    t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
    X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
    y[ix] = j
# lets visualize the data:
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.show()

# %%
W = 0.01 * np.random.randn(D,K)
b = np.zeros((1,K))

# %%
# initialize parameters randomly
W = 0.01 * np.random.randn(D,K)
b = np.zeros((1,K))

# some hyperparameters
step_size = 1e-0
reg = 1e-3 # regularization strength

# gradient descent loop
num_examples = X.shape[0]
for i in range(200):
  
  # evaluate class scores, [N x K]
    scores = np.dot(X, W) + b 
  
  # compute the class probabilities
    exp_scores = np.exp(scores)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True) # [N x K]
  
  # compute the loss: average cross-entropy loss and regularization
    corect_logprobs = -np.log(probs[range(num_examples),y])
    data_loss = np.sum(corect_logprobs)/num_examples
    reg_loss = 0.5*reg*np.sum(W*W)
    loss = data_loss + reg_loss
    if i % 10 == 0:
        print ("iteration %d: loss %f" % (i, loss))
  
  # compute the gradient on scores
    dscores = probs
    dscores[range(num_examples),y] -= 1
    dscores /= num_examples
  
  # backpropate the gradient to the parameters (W,b)
    dW = np.dot(X.T, dscores)
    db = np.sum(dscores, axis=0, keepdims=True)
  
    dW += reg*W # regularization gradient
  
  # perform a parameter update
    W += -step_size * dW
    b += -step_size * db
# Out:
# iteration 0: loss 1.096873
# iteration 10: loss 0.909111
# iteration 20: loss 0.839352
# iteration 30: loss 0.807740
# iteration 40: loss 0.791363
# iteration 50: loss 0.782099
# iteration 60: loss 0.776532
# iteration 70: loss 0.773041
# iteration 80: loss 0.770780
# iteration 90: loss 0.769279
# iteration 100: loss 0.768265
# iteration 110: loss 0.767569
# iteration 120: loss 0.767085
# iteration 130: loss 0.766746
# iteration 140: loss 0.766506
# iteration 150: loss 0.766335
# iteration 160: loss 0.766213
# iteration 170: loss 0.766125
# iteration 180: loss 0.766061
# iteration 190: loss 0.766015
